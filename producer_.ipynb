# %%
import requests

# Define the URL of the FastAPI endpoint
url = "http://127.0.0.1:8000/register-device"

# Define the schemas for different device types
schemas = {
    "gps": {
        "latitude": "float",
        "longitude": "float",
        "timestamp": "string"
    },
    "accel": {
        "acceleration_x": "float",
        "acceleration_y": "float",
        "acceleration_z": "float",
        "timestamp": "string"
    },
    "wind": {
        "speed": "float",
        "direction": "float",
        "timestamp": "string"
    },
    "player_temperature": {
        "temperature": "float",
        "timestamp": "string"
    },
    "player_heart_rate": {
        "heart_rate": "int",
        "timestamp": "string"
    }
}

# Number of devices to register for each type
num_devices = 10

# Loop through each device type and create multiple devices
for device_type, schema in schemas.items():
    for i in range(2, num_devices + 2):  # Starts at 2, ends at 11 (10 devices)
        device_name = f"{device_type}_{i}"
        payload = {
            "device_name": device_name,
            "schema": schema
        }
        
        # Send POST request to register the device
        response = requests.post(url, json=payload)
        
        # Print the status code and response for each device
        print(f"Registering device: {device_name}")
        print(f"Status Code: {response.status_code}")
        try:
            print(f"Response JSON: {response.json()}\n")
        except Exception as e:
            print(f"Error parsing response for {device_name}: {e}\n")

# %%
import asyncio
import websockets
import json
import random
import time
from datetime import datetime

# "Magic" Variables
WEBSOCKET_ENDPOINT_TEMPLATE = "ws://localhost:8000/send-stream/{device_id}/{run_id}"
DURATION_SECONDS = 500  # Total duration to send data
INTERVAL_SECONDS = 0.5  # Interval between data sends
OUT_OF_BOUNDS_INTERVAL = 100  # Every 100 messages, send an out-of-bounds message

# GPS-related boundaries and step sizes
PITCH_LAT_MIN = 40.0
PITCH_LAT_MAX = 40.0009
PITCH_LON_MIN = -75.0012
PITCH_LON_MAX = -75.0
STEP_SIZE_LAT = 0.00001  # Latitude step size for random walk (~1 meter)
STEP_SIZE_LON = 0.000015  # Longitude step size for random walk (~1 meter)

# Heart rate boundaries
HR_MIN = 70  # Minimum normal heart rate
HR_MAX = 140  # Maximum normal heart rate
HR_OUT_OF_BOUNDS_LOW = (30, 60)  # Out-of-bounds low range
HR_OUT_OF_BOUNDS_HIGH = (160, 200)  # Out-of-bounds high range

# Temperature boundaries
TEMP_MIN = 36.0  # Minimum normal temperature
TEMP_MAX = 39.0  # Maximum normal temperature
TEMP_OUT_OF_BOUNDS_LOW = (34.0, 35.5)  # Out-of-bounds low range
TEMP_OUT_OF_BOUNDS_HIGH = (39.5, 42.0)  # Out-of-bounds high range

def random_walk(current_lat, current_lon):
    """Perform a random walk within the boundaries of the football pitch."""
    new_lat = current_lat + random.uniform(-STEP_SIZE_LAT, STEP_SIZE_LAT)
    new_lon = current_lon + random.uniform(-STEP_SIZE_LON, STEP_SIZE_LON)
    new_lat = max(min(new_lat, PITCH_LAT_MAX), PITCH_LAT_MIN)
    new_lon = max(min(new_lon, PITCH_LON_MAX), PITCH_LON_MIN)
    return new_lat, new_lon

def generate_heart_rate():
    """Generate a random heart rate between HR_MIN and HR_MAX."""
    return random.randint(HR_MIN, HR_MAX)

def generate_temperature():
    """Generate a random temperature between TEMP_MIN and TEMP_MAX."""
    return round(random.uniform(TEMP_MIN, TEMP_MAX), 1)

async def send_synthetic_data(device_id, run_id, schema_type):
    websocket_endpoint = WEBSOCKET_ENDPOINT_TEMPLATE.format(device_id=device_id, run_id=run_id)

    async with websockets.connect(websocket_endpoint) as websocket:
        start_time = time.time()
        end_time = start_time + DURATION_SECONDS
        current_lat = (PITCH_LAT_MIN + PITCH_LAT_MAX) / 2
        current_lon = (PITCH_LON_MIN + PITCH_LON_MAX) / 2
        message_count = 0

        while time.time() < end_time:
            if schema_type == "gps":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_lat = PITCH_LAT_MAX + random.uniform(0.0001, 0.0005)
                    out_of_bounds_lon = PITCH_LON_MAX + random.uniform(0.0001, 0.0005)
                    data = {
                        "latitude": round(out_of_bounds_lat, 6),
                        "longitude": round(out_of_bounds_lon, 6),
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    current_lat, current_lon = random_walk(current_lat, current_lon)
                    data = {
                        "latitude": round(current_lat, 6),
                        "longitude": round(current_lon, 6),
                        "timestamp": datetime.utcnow().isoformat()
                    }
            elif schema_type == "heart_rate":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_hr = random.choice(
                        [random.randint(*HR_OUT_OF_BOUNDS_LOW), random.randint(*HR_OUT_OF_BOUNDS_HIGH)]
                    )
                    data = {
                        "heart_rate": out_of_bounds_hr,
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    heart_rate = generate_heart_rate()
                    data = {
                        "heart_rate": heart_rate,
                        "timestamp": datetime.utcnow().isoformat()
                    }
            elif schema_type == "temperature":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_temp = random.choice(
                        [round(random.uniform(*TEMP_OUT_OF_BOUNDS_LOW), 1), round(random.uniform(*TEMP_OUT_OF_BOUNDS_HIGH), 1)]
                    )
                    data = {
                        "temperature": out_of_bounds_temp,
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    temperature = generate_temperature()
                    data = {
                        "temperature": temperature,
                        "timestamp": datetime.utcnow().isoformat()
                    }

            data_str = json.dumps(data)
            await websocket.send(data_str)
            print(f"Sent data from {device_id} (run {run_id}): {data_str}")

            message_count += 1
            await asyncio.sleep(INTERVAL_SECONDS)

async def main():
    run_id = "run_001"
    
    # Generate tasks for 10 devices of each type
    tasks = [
        *[send_synthetic_data(f"gps_{i}", run_id, "gps") for i in range(1, 12)],
        *[send_synthetic_data(f"player_heart_rate_{i}", run_id, "heart_rate") for i in range(1, 2)],
        *[send_synthetic_data(f"player_temperature_{i}", run_id, "temperature") for i in range(1, 2)]
    ]
    
    await asyncio.gather(*tasks)

# Run the main function
await main()
# Out:
# C:\Users\larax\AppData\Local\Temp\ipykernel_16556\3911847572.py:75: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()
# Sent data from gps_3 (run run_001): {"latitude": 40.00045, "longitude": -75.000607, "timestamp": "2024-12-11T15:33:08.528650"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000455, "longitude": -75.0006, "timestamp": "2024-12-11T15:33:08.772004"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000456, "longitude": -75.000587, "timestamp": "2024-12-11T15:33:08.773129"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000442, "longitude": -75.0006, "timestamp": "2024-12-11T15:33:08.895470"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000456, "longitude": -75.000596, "timestamp": "2024-12-11T15:33:09.040895"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000458, "longitude": -75.000588, "timestamp": "2024-12-11T15:33:09.274141"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000447, "longitude": -75.000586, "timestamp": "2024-12-11T15:33:09.274141"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000445, "longitude": -75.00059, "timestamp": "2024-12-11T15:33:09.384186"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000457, "longitude": -75.000585, "timestamp": "2024-12-11T15:33:09.554952"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000461, "longitude": -75.000588, "timestamp": "2024-12-11T15:33:09.788947"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000449, "longitude": -75.00058, "timestamp": "2024-12-11T15:33:09.788947"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000446, "longitude": -75.000597, "timestamp": "2024-12-11T15:33:09.895879"}
# Sent data from gps_5 (run run_001): {"latitude": 40.00046, "longitude": -75.0006, "timestamp": "2024-12-11T15:33:09.932647"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000449, "longitude": -75.000607, "timestamp": "2024-12-11T15:33:09.933802"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000442, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:09.936041"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000456, "longitude": -75.000606, "timestamp": "2024-12-11T15:33:09.937706"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000456, "longitude": -75.000597, "timestamp": "2024-12-11T15:33:09.938753"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000446, "longitude": -75.000612, "timestamp": "2024-12-11T15:33:09.939302"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-11T15:33:09.939903"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 102, "timestamp": "2024-12-11T15:33:09.941494"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000455, "longitude": -75.000605, "timestamp": "2024-12-11T15:33:09.941621"}
# C:\Users\larax\AppData\Local\Temp\ipykernel_16556\3911847572.py:105: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()
# C:\Users\larax\AppData\Local\Temp\ipykernel_16556\3911847572.py:90: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()
# Sent data from gps_3 (run run_001): {"latitude": 40.000458, "longitude": -75.000572, "timestamp": "2024-12-11T15:33:10.079210"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000455, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:10.298886"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000452, "longitude": -75.000586, "timestamp": "2024-12-11T15:33:10.298945"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000451, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:10.408674"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000451, "longitude": -75.000604, "timestamp": "2024-12-11T15:33:10.440248"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000461, "longitude": -75.000607, "timestamp": "2024-12-11T15:33:10.440248"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000448, "longitude": -75.000585, "timestamp": "2024-12-11T15:33:10.441265"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000436, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:10.441265"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000465, "longitude": -75.000598, "timestamp": "2024-12-11T15:33:10.441265"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000446, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:10.442439"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 108, "timestamp": "2024-12-11T15:33:10.442439"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000452, "longitude": -75.000606, "timestamp": "2024-12-11T15:33:10.442439"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-11T15:33:10.443438"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000466, "longitude": -75.000571, "timestamp": "2024-12-11T15:33:10.597775"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000461, "longitude": -75.000574, "timestamp": "2024-12-11T15:33:10.816879"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000464, "longitude": -75.000584, "timestamp": "2024-12-11T15:33:10.817883"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000457, "longitude": -75.000608, "timestamp": "2024-12-11T15:33:10.926466"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000449, "longitude": -75.000613, "timestamp": "2024-12-11T15:33:10.942529"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-11T15:33:10.942529"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000456, "longitude": -75.000598, "timestamp": "2024-12-11T15:33:10.942529"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000445, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:10.943878"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000442, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:10.943878"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000451, "longitude": -75.000597, "timestamp": "2024-12-11T15:33:10.943878"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 106, "timestamp": "2024-12-11T15:33:10.943878"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000431, "longitude": -75.000585, "timestamp": "2024-12-11T15:33:10.944897"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000459, "longitude": -75.000597, "timestamp": "2024-12-11T15:33:10.944897"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000464, "longitude": -75.000567, "timestamp": "2024-12-11T15:33:11.098930"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000469, "longitude": -75.000586, "timestamp": "2024-12-11T15:33:11.332986"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000454, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:11.333984"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000449, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:11.441719"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000449, "longitude": -75.000623, "timestamp": "2024-12-11T15:33:11.441719"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.3, "timestamp": "2024-12-11T15:33:11.441719"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000459, "longitude": -75.000596, "timestamp": "2024-12-11T15:33:11.441719"}
# Sent data from gps_7 (run run_001): {"latitude": 40.00043, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:11.441719"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 129, "timestamp": "2024-12-11T15:33:11.443233"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000449, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:11.443233"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000439, "longitude": -75.000569, "timestamp": "2024-12-11T15:33:11.443233"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000448, "longitude": -75.00061, "timestamp": "2024-12-11T15:33:11.444247"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000455, "longitude": -75.000586, "timestamp": "2024-12-11T15:33:11.444247"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000458, "longitude": -75.000578, "timestamp": "2024-12-11T15:33:11.612128"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000451, "longitude": -75.000572, "timestamp": "2024-12-11T15:33:11.845824"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000467, "longitude": -75.000598, "timestamp": "2024-12-11T15:33:11.846937"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000444, "longitude": -75.000614, "timestamp": "2024-12-11T15:33:11.954200"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000458, "longitude": -75.000617, "timestamp": "2024-12-11T15:33:11.954200"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000446, "longitude": -75.000598, "timestamp": "2024-12-11T15:33:11.955199"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-11T15:33:11.955199"}
# Sent data from gps_9 (run run_001): {"latitude": 40.00044, "longitude": -75.000589, "timestamp": "2024-12-11T15:33:11.955199"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000446, "longitude": -75.000623, "timestamp": "2024-12-11T15:33:11.956203"}
# Sent data from gps_8 (run run_001): {"latitude": 40.00044, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:11.956203"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000453, "longitude": -75.000584, "timestamp": "2024-12-11T15:33:11.956203"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000436, "longitude": -75.000594, "timestamp": "2024-12-11T15:33:11.956203"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 125, "timestamp": "2024-12-11T15:33:11.957208"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000455, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:12.125509"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00046, "longitude": -75.0006, "timestamp": "2024-12-11T15:33:12.357765"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000443, "longitude": -75.000559, "timestamp": "2024-12-11T15:33:12.358764"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000446, "longitude": -75.00061, "timestamp": "2024-12-11T15:33:12.467361"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000461, "longitude": -75.000609, "timestamp": "2024-12-11T15:33:12.467361"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 116, "timestamp": "2024-12-11T15:33:12.468874"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000445, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:12.468874"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-11T15:33:12.468874"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000437, "longitude": -75.000584, "timestamp": "2024-12-11T15:33:12.469890"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000444, "longitude": -75.000602, "timestamp": "2024-12-11T15:33:12.469890"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000445, "longitude": -75.000591, "timestamp": "2024-12-11T15:33:12.470899"}
# Sent data from gps_9 (run run_001): {"latitude": 40.00043, "longitude": -75.000591, "timestamp": "2024-12-11T15:33:12.470899"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000438, "longitude": -75.000608, "timestamp": "2024-12-11T15:33:12.471914"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000453, "longitude": -75.000596, "timestamp": "2024-12-11T15:33:12.641544"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000446, "longitude": -75.000555, "timestamp": "2024-12-11T15:33:12.872510"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000461, "longitude": -75.000612, "timestamp": "2024-12-11T15:33:12.873515"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000452, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:12.980298"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000453, "longitude": -75.000606, "timestamp": "2024-12-11T15:33:12.981299"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000444, "longitude": -75.000614, "timestamp": "2024-12-11T15:33:12.981299"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 80, "timestamp": "2024-12-11T15:33:12.981299"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000444, "longitude": -75.000587, "timestamp": "2024-12-11T15:33:12.982293"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000444, "longitude": -75.000607, "timestamp": "2024-12-11T15:33:12.982293"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000428, "longitude": -75.000581, "timestamp": "2024-12-11T15:33:12.982293"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000438, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:12.982293"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-11T15:33:12.982293"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000435, "longitude": -75.000573, "timestamp": "2024-12-11T15:33:12.983295"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000462, "longitude": -75.000585, "timestamp": "2024-12-11T15:33:13.152660"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000455, "longitude": -75.000613, "timestamp": "2024-12-11T15:33:13.386016"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000452, "longitude": -75.000563, "timestamp": "2024-12-11T15:33:13.386016"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000448, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:13.495735"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000447, "longitude": -75.000594, "timestamp": "2024-12-11T15:33:13.495735"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000433, "longitude": -75.00058, "timestamp": "2024-12-11T15:33:13.496740"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000445, "longitude": -75.000609, "timestamp": "2024-12-11T15:33:13.496740"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 89, "timestamp": "2024-12-11T15:33:13.496740"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000427, "longitude": -75.000578, "timestamp": "2024-12-11T15:33:13.497738"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.3, "timestamp": "2024-12-11T15:33:13.497738"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000432, "longitude": -75.000579, "timestamp": "2024-12-11T15:33:13.497738"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000442, "longitude": -75.00059, "timestamp": "2024-12-11T15:33:13.498740"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000452, "longitude": -75.000621, "timestamp": "2024-12-11T15:33:13.498740"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000468, "longitude": -75.000591, "timestamp": "2024-12-11T15:33:13.670291"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000452, "longitude": -75.000558, "timestamp": "2024-12-11T15:33:13.904015"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000447, "longitude": -75.000618, "timestamp": "2024-12-11T15:33:13.905019"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000439, "longitude": -75.000613, "timestamp": "2024-12-11T15:33:14.013498"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000452, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:14.013498"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000459, "longitude": -75.000632, "timestamp": "2024-12-11T15:33:14.014495"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000429, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:14.014495"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000438, "longitude": -75.00062, "timestamp": "2024-12-11T15:33:14.015497"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.1, "timestamp": "2024-12-11T15:33:14.015497"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000434, "longitude": -75.000602, "timestamp": "2024-12-11T15:33:14.016495"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000432, "longitude": -75.000576, "timestamp": "2024-12-11T15:33:14.016495"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 134, "timestamp": "2024-12-11T15:33:14.016495"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000418, "longitude": -75.000581, "timestamp": "2024-12-11T15:33:14.016495"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000473, "longitude": -75.000605, "timestamp": "2024-12-11T15:33:14.183188"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00045, "longitude": -75.000614, "timestamp": "2024-12-11T15:33:14.416680"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000455, "longitude": -75.000563, "timestamp": "2024-12-11T15:33:14.417680"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000434, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:14.525160"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000445, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:14.526159"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000412, "longitude": -75.000575, "timestamp": "2024-12-11T15:33:14.526159"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000452, "longitude": -75.000627, "timestamp": "2024-12-11T15:33:14.527162"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000424, "longitude": -75.000586, "timestamp": "2024-12-11T15:33:14.527162"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000426, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:14.527162"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 111, "timestamp": "2024-12-11T15:33:14.528687"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000432, "longitude": -75.000567, "timestamp": "2024-12-11T15:33:14.528755"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000441, "longitude": -75.00061, "timestamp": "2024-12-11T15:33:14.528755"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-11T15:33:14.529712"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000473, "longitude": -75.000613, "timestamp": "2024-12-11T15:33:14.698918"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000451, "longitude": -75.000562, "timestamp": "2024-12-11T15:33:14.932968"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000443, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:14.934971"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000438, "longitude": -75.000594, "timestamp": "2024-12-11T15:33:15.041721"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000449, "longitude": -75.000606, "timestamp": "2024-12-11T15:33:15.041721"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-11T15:33:15.041721"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000416, "longitude": -75.000561, "timestamp": "2024-12-11T15:33:15.043228"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000462, "longitude": -75.000637, "timestamp": "2024-12-11T15:33:15.044237"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 126, "timestamp": "2024-12-11T15:33:15.044237"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000435, "longitude": -75.00062, "timestamp": "2024-12-11T15:33:15.044237"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000434, "longitude": -75.000568, "timestamp": "2024-12-11T15:33:15.044237"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000416, "longitude": -75.000581, "timestamp": "2024-12-11T15:33:15.045236"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000417, "longitude": -75.000624, "timestamp": "2024-12-11T15:33:15.045236"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000475, "longitude": -75.000615, "timestamp": "2024-12-11T15:33:15.210454"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000446, "longitude": -75.000604, "timestamp": "2024-12-11T15:33:15.461114"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000443, "longitude": -75.000556, "timestamp": "2024-12-11T15:33:15.461621"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000445, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:15.540044"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000444, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:15.540044"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000418, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:15.541051"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-11T15:33:15.541051"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000417, "longitude": -75.000569, "timestamp": "2024-12-11T15:33:15.541051"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000432, "longitude": -75.000626, "timestamp": "2024-12-11T15:33:15.542043"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000422, "longitude": -75.000566, "timestamp": "2024-12-11T15:33:15.542043"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000437, "longitude": -75.000581, "timestamp": "2024-12-11T15:33:15.542043"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000471, "longitude": -75.000643, "timestamp": "2024-12-11T15:33:15.542043"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 125, "timestamp": "2024-12-11T15:33:15.543054"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000469, "longitude": -75.00061, "timestamp": "2024-12-11T15:33:15.713256"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000452, "longitude": -75.000567, "timestamp": "2024-12-11T15:33:15.977484"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000441, "longitude": -75.000604, "timestamp": "2024-12-11T15:33:15.977484"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000444, "longitude": -75.000601, "timestamp": "2024-12-11T15:33:16.039565"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000444, "longitude": -75.000622, "timestamp": "2024-12-11T15:33:16.039565"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 107, "timestamp": "2024-12-11T15:33:16.039565"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000413, "longitude": -75.000618, "timestamp": "2024-12-11T15:33:16.039565"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-11T15:33:16.040580"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000412, "longitude": -75.000574, "timestamp": "2024-12-11T15:33:16.040580"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000469, "longitude": -75.000646, "timestamp": "2024-12-11T15:33:16.041657"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000441, "longitude": -75.000567, "timestamp": "2024-12-11T15:33:16.041657"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000424, "longitude": -75.000554, "timestamp": "2024-12-11T15:33:16.041657"}
# Sent data from gps_10 (run run_001): {"latitude": 40.00043, "longitude": -75.000619, "timestamp": "2024-12-11T15:33:16.041657"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000469, "longitude": -75.000624, "timestamp": "2024-12-11T15:33:16.224047"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000434, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:16.504523"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000445, "longitude": -75.000569, "timestamp": "2024-12-11T15:33:16.505513"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000448, "longitude": -75.000598, "timestamp": "2024-12-11T15:33:16.567978"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000446, "longitude": -75.000631, "timestamp": "2024-12-11T15:33:16.568987"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000432, "longitude": -75.000619, "timestamp": "2024-12-11T15:33:16.569500"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 99, "timestamp": "2024-12-11T15:33:16.569500"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000405, "longitude": -75.000625, "timestamp": "2024-12-11T15:33:16.569500"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000478, "longitude": -75.000647, "timestamp": "2024-12-11T15:33:16.570523"}
# Sent data from gps_9 (run run_001): {"latitude": 40.00043, "longitude": -75.000556, "timestamp": "2024-12-11T15:33:16.570523"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000439, "longitude": -75.000563, "timestamp": "2024-12-11T15:33:16.571522"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-11T15:33:16.571522"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000417, "longitude": -75.000568, "timestamp": "2024-12-11T15:33:16.571522"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000472, "longitude": -75.000612, "timestamp": "2024-12-11T15:33:16.722505"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000444, "longitude": -75.000564, "timestamp": "2024-12-11T15:33:17.016496"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00043, "longitude": -75.000618, "timestamp": "2024-12-11T15:33:17.017503"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000456, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:17.077245"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000446, "longitude": -75.000638, "timestamp": "2024-12-11T15:33:17.077245"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000426, "longitude": -75.000632, "timestamp": "2024-12-11T15:33:17.077245"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 89, "timestamp": "2024-12-11T15:33:17.077245"}
# Sent data from gps_5 (run run_001): {"latitude": 40.00041, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:17.078761"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000473, "longitude": -75.000635, "timestamp": "2024-12-11T15:33:17.078761"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000408, "longitude": -75.00056, "timestamp": "2024-12-11T15:33:17.079784"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000439, "longitude": -75.000565, "timestamp": "2024-12-11T15:33:17.080779"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-11T15:33:17.080779"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000439, "longitude": -75.000573, "timestamp": "2024-12-11T15:33:17.081797"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000472, "longitude": -75.000626, "timestamp": "2024-12-11T15:33:17.233452"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000424, "longitude": -75.000633, "timestamp": "2024-12-11T15:33:17.514768"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000441, "longitude": -75.000567, "timestamp": "2024-12-11T15:33:17.514768"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000455, "longitude": -75.000587, "timestamp": "2024-12-11T15:33:17.591664"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000448, "longitude": -75.000632, "timestamp": "2024-12-11T15:33:17.592663"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000433, "longitude": -75.000565, "timestamp": "2024-12-11T15:33:17.592663"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000418, "longitude": -75.000631, "timestamp": "2024-12-11T15:33:17.593666"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000415, "longitude": -75.000557, "timestamp": "2024-12-11T15:33:17.593666"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-11T15:33:17.594667"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000429, "longitude": -75.000558, "timestamp": "2024-12-11T15:33:17.594667"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 134, "timestamp": "2024-12-11T15:33:17.595669"}
# Sent data from gps_5 (run run_001): {"latitude": 40.0004, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:17.595669"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000483, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:17.596664"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000471, "longitude": -75.000618, "timestamp": "2024-12-11T15:33:17.746949"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000434, "longitude": -75.000575, "timestamp": "2024-12-11T15:33:18.026073"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000427, "longitude": -75.000623, "timestamp": "2024-12-11T15:33:18.026073"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000464, "longitude": -75.000591, "timestamp": "2024-12-11T15:33:18.103928"}
# Sent data from gps_6 (run run_001): {"latitude": 40.00044, "longitude": -75.000635, "timestamp": "2024-12-11T15:33:18.103928"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000475, "longitude": -75.000628, "timestamp": "2024-12-11T15:33:18.105012"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000429, "longitude": -75.000572, "timestamp": "2024-12-11T15:33:18.105012"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000413, "longitude": -75.000624, "timestamp": "2024-12-11T15:33:18.105012"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000434, "longitude": -75.000562, "timestamp": "2024-12-11T15:33:18.106020"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000402, "longitude": -75.000617, "timestamp": "2024-12-11T15:33:18.107021"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 79, "timestamp": "2024-12-11T15:33:18.107021"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000415, "longitude": -75.000552, "timestamp": "2024-12-11T15:33:18.108024"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-11T15:33:18.108024"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000475, "longitude": -75.000621, "timestamp": "2024-12-11T15:33:18.260104"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000425, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:18.539451"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000431, "longitude": -75.000574, "timestamp": "2024-12-11T15:33:18.540467"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000433, "longitude": -75.000623, "timestamp": "2024-12-11T15:33:18.616938"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000468, "longitude": -75.0006, "timestamp": "2024-12-11T15:33:18.616938"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-11T15:33:18.617941"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000395, "longitude": -75.000625, "timestamp": "2024-12-11T15:33:18.617941"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000417, "longitude": -75.000541, "timestamp": "2024-12-11T15:33:18.618941"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000475, "longitude": -75.000619, "timestamp": "2024-12-11T15:33:18.618941"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 94, "timestamp": "2024-12-11T15:33:18.618941"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000422, "longitude": -75.000639, "timestamp": "2024-12-11T15:33:18.618941"}
# Sent data from gps_9 (run run_001): {"latitude": 40.00043, "longitude": -75.000557, "timestamp": "2024-12-11T15:33:18.620237"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000426, "longitude": -75.000585, "timestamp": "2024-12-11T15:33:18.620237"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000481, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:18.774800"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000424, "longitude": -75.000563, "timestamp": "2024-12-11T15:33:19.055371"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000424, "longitude": -75.000617, "timestamp": "2024-12-11T15:33:19.055371"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000435, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:19.118938"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000433, "longitude": -75.000587, "timestamp": "2024-12-11T15:33:19.119853"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000426, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:19.119853"}
# Sent data from gps_9 (run run_001): {"latitude": 40.00043, "longitude": -75.000552, "timestamp": "2024-12-11T15:33:19.120855"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000394, "longitude": -75.000627, "timestamp": "2024-12-11T15:33:19.120855"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000479, "longitude": -75.000606, "timestamp": "2024-12-11T15:33:19.121852"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 120, "timestamp": "2024-12-11T15:33:19.121852"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000419, "longitude": -75.000545, "timestamp": "2024-12-11T15:33:19.121852"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000477, "longitude": -75.000587, "timestamp": "2024-12-11T15:33:19.123450"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-11T15:33:19.123450"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000488, "longitude": -75.000632, "timestamp": "2024-12-11T15:33:19.291710"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000418, "longitude": -75.000627, "timestamp": "2024-12-11T15:33:19.572604"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000428, "longitude": -75.00055, "timestamp": "2024-12-11T15:33:19.573613"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-11T15:33:19.634304"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000412, "longitude": -75.000532, "timestamp": "2024-12-11T15:33:19.635306"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000472, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:19.636317"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000438, "longitude": -75.000605, "timestamp": "2024-12-11T15:33:19.636317"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000426, "longitude": -75.000555, "timestamp": "2024-12-11T15:33:19.637312"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000485, "longitude": -75.000596, "timestamp": "2024-12-11T15:33:19.637312"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 138, "timestamp": "2024-12-11T15:33:19.637312"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000404, "longitude": -75.000635, "timestamp": "2024-12-11T15:33:19.637312"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000424, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:19.638921"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000427, "longitude": -75.000619, "timestamp": "2024-12-11T15:33:19.638921"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000482, "longitude": -75.000627, "timestamp": "2024-12-11T15:33:19.806216"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000437, "longitude": -75.000554, "timestamp": "2024-12-11T15:33:20.072581"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000417, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:20.073090"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000424, "longitude": -75.000628, "timestamp": "2024-12-11T15:33:20.150470"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000401, "longitude": -75.000637, "timestamp": "2024-12-11T15:33:20.150470"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000428, "longitude": -75.000588, "timestamp": "2024-12-11T15:33:20.151470"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-11T15:33:20.151470"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000444, "longitude": -75.000605, "timestamp": "2024-12-11T15:33:20.152476"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000493, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:20.152476"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 95, "timestamp": "2024-12-11T15:33:20.152476"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000425, "longitude": -75.000567, "timestamp": "2024-12-11T15:33:20.153474"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000406, "longitude": -75.000538, "timestamp": "2024-12-11T15:33:20.153474"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000468, "longitude": -75.000589, "timestamp": "2024-12-11T15:33:20.154474"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000488, "longitude": -75.000617, "timestamp": "2024-12-11T15:33:20.321836"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000424, "longitude": -75.000619, "timestamp": "2024-12-11T15:33:20.584541"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000433, "longitude": -75.000551, "timestamp": "2024-12-11T15:33:20.585542"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000473, "longitude": -75.000597, "timestamp": "2024-12-11T15:33:20.678141"}
# Sent data from gps_9 (run run_001): {"latitude": 40.00043, "longitude": -75.00057, "timestamp": "2024-12-11T15:33:20.678141"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000414, "longitude": -75.000532, "timestamp": "2024-12-11T15:33:20.679143"}
# Sent data from gps_10 (run run_001): {"latitude": 40.00043, "longitude": -75.000621, "timestamp": "2024-12-11T15:33:20.679143"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-11T15:33:20.680292"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000498, "longitude": -75.000607, "timestamp": "2024-12-11T15:33:20.680292"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 128, "timestamp": "2024-12-11T15:33:20.680292"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000452, "longitude": -75.000609, "timestamp": "2024-12-11T15:33:20.681294"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000397, "longitude": -75.000647, "timestamp": "2024-12-11T15:33:20.681294"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000424, "longitude": -75.000575, "timestamp": "2024-12-11T15:33:20.682324"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000492, "longitude": -75.000622, "timestamp": "2024-12-11T15:33:20.832131"}
# Sent data from gps_2 (run run_001): {"latitude": 40.00044, "longitude": -75.000536, "timestamp": "2024-12-11T15:33:21.082995"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000419, "longitude": -75.000618, "timestamp": "2024-12-11T15:33:21.084003"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000468, "longitude": -75.000606, "timestamp": "2024-12-11T15:33:21.192514"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000424, "longitude": -75.000636, "timestamp": "2024-12-11T15:33:21.193512"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000424, "longitude": -75.000574, "timestamp": "2024-12-11T15:33:21.193512"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000423, "longitude": -75.000531, "timestamp": "2024-12-11T15:33:21.195512"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000419, "longitude": -75.000573, "timestamp": "2024-12-11T15:33:21.195512"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000443, "longitude": -75.000613, "timestamp": "2024-12-11T15:33:21.196518"}
# Sent data from gps_5 (run run_001): {"latitude": 40.00039, "longitude": -75.000656, "timestamp": "2024-12-11T15:33:21.197518"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000498, "longitude": -75.000612, "timestamp": "2024-12-11T15:33:21.199096"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 135, "timestamp": "2024-12-11T15:33:21.201048"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-11T15:33:21.202049"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000489, "longitude": -75.000628, "timestamp": "2024-12-11T15:33:21.332814"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00042, "longitude": -75.000614, "timestamp": "2024-12-11T15:33:21.594618"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000432, "longitude": -75.000536, "timestamp": "2024-12-11T15:33:21.595617"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000429, "longitude": -75.000521, "timestamp": "2024-12-11T15:33:21.702829"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000416, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:21.703829"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000432, "longitude": -75.000587, "timestamp": "2024-12-11T15:33:21.703829"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000471, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:21.704826"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000504, "longitude": -75.000621, "timestamp": "2024-12-11T15:33:21.705829"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 102, "timestamp": "2024-12-11T15:33:21.705829"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.9, "timestamp": "2024-12-11T15:33:21.705829"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000439, "longitude": -75.000628, "timestamp": "2024-12-11T15:33:21.705829"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000396, "longitude": -75.000668, "timestamp": "2024-12-11T15:33:21.706824"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000412, "longitude": -75.000568, "timestamp": "2024-12-11T15:33:21.706824"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000488, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:21.842258"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000427, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:22.108982"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000433, "longitude": -75.000534, "timestamp": "2024-12-11T15:33:22.108982"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000446, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:22.217228"}
# Sent data from gps_11 (run run_001): {"latitude": 40.00042, "longitude": -75.000566, "timestamp": "2024-12-11T15:33:22.217228"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000404, "longitude": -75.000672, "timestamp": "2024-12-11T15:33:22.217228"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000475, "longitude": -75.000603, "timestamp": "2024-12-11T15:33:22.217228"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-11T15:33:22.218742"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-11T15:33:22.218742"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000501, "longitude": -75.000622, "timestamp": "2024-12-11T15:33:22.218742"}
# Sent data from gps_8 (run run_001): {"latitude": 40.00042, "longitude": -75.000534, "timestamp": "2024-12-11T15:33:22.219756"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000421, "longitude": -75.000639, "timestamp": "2024-12-11T15:33:22.219756"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000435, "longitude": -75.000574, "timestamp": "2024-12-11T15:33:22.220763"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000494, "longitude": -75.000602, "timestamp": "2024-12-11T15:33:22.357534"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000426, "longitude": -75.000522, "timestamp": "2024-12-11T15:33:22.619906"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000437, "longitude": -75.000621, "timestamp": "2024-12-11T15:33:22.619906"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000435, "longitude": -75.000564, "timestamp": "2024-12-11T15:33:22.728118"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000417, "longitude": -75.000526, "timestamp": "2024-12-11T15:33:22.729122"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000415, "longitude": -75.000632, "timestamp": "2024-12-11T15:33:22.729629"}
# Sent data from gps_6 (run run_001): {"latitude": 40.00045, "longitude": -75.000627, "timestamp": "2024-12-11T15:33:22.730643"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000476, "longitude": -75.000594, "timestamp": "2024-12-11T15:33:22.731652"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.1, "timestamp": "2024-12-11T15:33:22.732657"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000494, "longitude": -75.000626, "timestamp": "2024-12-11T15:33:22.732657"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 122, "timestamp": "2024-12-11T15:33:22.733657"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000428, "longitude": -75.000572, "timestamp": "2024-12-11T15:33:22.734655"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000402, "longitude": -75.000674, "timestamp": "2024-12-11T15:33:22.735653"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000496, "longitude": -75.000588, "timestamp": "2024-12-11T15:33:22.868075"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000435, "longitude": -75.000633, "timestamp": "2024-12-11T15:33:23.133904"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000435, "longitude": -75.000517, "timestamp": "2024-12-11T15:33:23.134911"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000408, "longitude": -75.000671, "timestamp": "2024-12-11T15:33:23.229006"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 75, "timestamp": "2024-12-11T15:33:23.229951"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000438, "longitude": -75.000575, "timestamp": "2024-12-11T15:33:23.229951"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000443, "longitude": -75.000559, "timestamp": "2024-12-11T15:33:23.230949"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000458, "longitude": -75.000638, "timestamp": "2024-12-11T15:33:23.230949"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-11T15:33:23.231954"}
# Sent data from gps_7 (run run_001): {"latitude": 40.0005, "longitude": -75.000636, "timestamp": "2024-12-11T15:33:23.231954"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000485, "longitude": -75.000593, "timestamp": "2024-12-11T15:33:23.232971"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000412, "longitude": -75.000538, "timestamp": "2024-12-11T15:33:23.232971"}
# Sent data from gps_10 (run run_001): {"latitude": 40.00041, "longitude": -75.000639, "timestamp": "2024-12-11T15:33:23.232971"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000487, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:23.381743"}
# Sent data from gps_2 (run run_001): {"latitude": 40.00043, "longitude": -75.000519, "timestamp": "2024-12-11T15:33:23.661212"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000439, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:23.662197"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000406, "longitude": -75.00065, "timestamp": "2024-12-11T15:33:23.754154"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000481, "longitude": -75.000595, "timestamp": "2024-12-11T15:33:23.754154"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000413, "longitude": -75.000546, "timestamp": "2024-12-11T15:33:23.755154"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000415, "longitude": -75.000664, "timestamp": "2024-12-11T15:33:23.755154"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000453, "longitude": -75.00057, "timestamp": "2024-12-11T15:33:23.756163"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.2, "timestamp": "2024-12-11T15:33:23.756163"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000498, "longitude": -75.000649, "timestamp": "2024-12-11T15:33:23.757162"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000448, "longitude": -75.000628, "timestamp": "2024-12-11T15:33:23.757162"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-11T15:33:23.757162"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000446, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:23.757162"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000482, "longitude": -75.000604, "timestamp": "2024-12-11T15:33:23.894342"}
# ...
# Sent data from gps_1 (run run_001): {"latitude": 40.000465, "longitude": -75.000557, "timestamp": "2024-12-11T15:33:31.853909"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000408, "longitude": -75.000529, "timestamp": "2024-12-11T15:33:31.853909"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000498, "longitude": -75.000551, "timestamp": "2024-12-11T15:33:31.961265"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000457, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:31.961265"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000407, "longitude": -75.000655, "timestamp": "2024-12-11T15:33:31.962262"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000457, "longitude": -75.000546, "timestamp": "2024-12-11T15:33:31.962262"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000444, "longitude": -75.000596, "timestamp": "2024-12-11T15:33:31.963260"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000434, "longitude": -75.000627, "timestamp": "2024-12-11T15:33:31.965259"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000501, "longitude": -75.000681, "timestamp": "2024-12-11T15:33:31.965259"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.5, "timestamp": "2024-12-11T15:33:31.965259"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 102, "timestamp": "2024-12-11T15:33:31.966264"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000423, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:31.966264"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000491, "longitude": -75.000566, "timestamp": "2024-12-11T15:33:32.086261"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000404, "longitude": -75.000537, "timestamp": "2024-12-11T15:33:32.368078"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000456, "longitude": -75.000546, "timestamp": "2024-12-11T15:33:32.369081"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000491, "longitude": -75.000541, "timestamp": "2024-12-11T15:33:32.462469"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000454, "longitude": -75.000586, "timestamp": "2024-12-11T15:33:32.463469"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000429, "longitude": -75.0006, "timestamp": "2024-12-11T15:33:32.463469"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000416, "longitude": -75.000642, "timestamp": "2024-12-11T15:33:32.463469"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000461, "longitude": -75.000546, "timestamp": "2024-12-11T15:33:32.463469"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000501, "longitude": -75.000691, "timestamp": "2024-12-11T15:33:32.463469"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 140, "timestamp": "2024-12-11T15:33:32.464473"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-11T15:33:32.464473"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000439, "longitude": -75.000582, "timestamp": "2024-12-11T15:33:32.465474"}
# Sent data from gps_6 (run run_001): {"latitude": 40.00044, "longitude": -75.000634, "timestamp": "2024-12-11T15:33:32.465474"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000493, "longitude": -75.000578, "timestamp": "2024-12-11T15:33:32.587248"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000446, "longitude": -75.000543, "timestamp": "2024-12-11T15:33:32.883265"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000407, "longitude": -75.000552, "timestamp": "2024-12-11T15:33:32.884260"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000494, "longitude": -75.000528, "timestamp": "2024-12-11T15:33:32.977287"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000452, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:32.977287"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000443, "longitude": -75.000636, "timestamp": "2024-12-11T15:33:32.977287"}
# Sent data from gps_5 (run run_001): {"latitude": 40.00043, "longitude": -75.000614, "timestamp": "2024-12-11T15:33:32.977287"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000425, "longitude": -75.000629, "timestamp": "2024-12-11T15:33:32.977287"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 112, "timestamp": "2024-12-11T15:33:32.977287"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000445, "longitude": -75.000585, "timestamp": "2024-12-11T15:33:32.978797"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-11T15:33:32.978797"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000458, "longitude": -75.000558, "timestamp": "2024-12-11T15:33:32.978797"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000492, "longitude": -75.000704, "timestamp": "2024-12-11T15:33:32.979816"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000496, "longitude": -75.000588, "timestamp": "2024-12-11T15:33:33.101459"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000407, "longitude": -75.000549, "timestamp": "2024-12-11T15:33:33.412463"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000454, "longitude": -75.00055, "timestamp": "2024-12-11T15:33:33.412463"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000485, "longitude": -75.000523, "timestamp": "2024-12-11T15:33:33.504752"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000461, "longitude": -75.000599, "timestamp": "2024-12-11T15:33:33.505898"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000494, "longitude": -75.000699, "timestamp": "2024-12-11T15:33:33.505898"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000434, "longitude": -75.000648, "timestamp": "2024-12-11T15:33:33.506924"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000427, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:33.506924"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000441, "longitude": -75.000591, "timestamp": "2024-12-11T15:33:33.507911"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000466, "longitude": -75.000544, "timestamp": "2024-12-11T15:33:33.507911"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-11T15:33:33.508909"}
# Sent data from gps_10 (run run_001): {"latitude": 40.00043, "longitude": -75.000615, "timestamp": "2024-12-11T15:33:33.509421"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 132, "timestamp": "2024-12-11T15:33:33.509421"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000496, "longitude": -75.000575, "timestamp": "2024-12-11T15:33:33.597694"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000453, "longitude": -75.00055, "timestamp": "2024-12-11T15:33:33.912482"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000409, "longitude": -75.000563, "timestamp": "2024-12-11T15:33:33.913480"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000494, "longitude": -75.000518, "timestamp": "2024-12-11T15:33:34.021055"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000452, "longitude": -75.000589, "timestamp": "2024-12-11T15:33:34.021055"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000494, "longitude": -75.000702, "timestamp": "2024-12-11T15:33:34.021055"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000437, "longitude": -75.000658, "timestamp": "2024-12-11T15:33:34.022062"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000433, "longitude": -75.000618, "timestamp": "2024-12-11T15:33:34.022062"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000444, "longitude": -75.000595, "timestamp": "2024-12-11T15:33:34.022062"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 76, "timestamp": "2024-12-11T15:33:34.023059"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000464, "longitude": -75.000538, "timestamp": "2024-12-11T15:33:34.023059"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000428, "longitude": -75.000627, "timestamp": "2024-12-11T15:33:34.024063"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.9, "timestamp": "2024-12-11T15:33:34.024063"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000498, "longitude": -75.000571, "timestamp": "2024-12-11T15:33:34.099430"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000417, "longitude": -75.000563, "timestamp": "2024-12-11T15:33:34.425758"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000445, "longitude": -75.00056, "timestamp": "2024-12-11T15:33:34.426760"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000485, "longitude": -75.000529, "timestamp": "2024-12-11T15:33:34.534869"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000459, "longitude": -75.000584, "timestamp": "2024-12-11T15:33:34.535381"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000489, "longitude": -75.000693, "timestamp": "2024-12-11T15:33:34.535381"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 102, "timestamp": "2024-12-11T15:33:34.536398"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000443, "longitude": -75.000656, "timestamp": "2024-12-11T15:33:34.536398"}
# Sent data from gps_5 (run run_001): {"latitude": 40.00044, "longitude": -75.000615, "timestamp": "2024-12-11T15:33:34.536398"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000439, "longitude": -75.000602, "timestamp": "2024-12-11T15:33:34.536398"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-11T15:33:34.536398"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000434, "longitude": -75.000631, "timestamp": "2024-12-11T15:33:34.536398"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000465, "longitude": -75.000534, "timestamp": "2024-12-11T15:33:34.537396"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000502, "longitude": -75.000564, "timestamp": "2024-12-11T15:33:34.612236"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000452, "longitude": -75.000574, "timestamp": "2024-12-11T15:33:34.925109"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000419, "longitude": -75.000554, "timestamp": "2024-12-11T15:33:34.926109"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000481, "longitude": -75.000528, "timestamp": "2024-12-11T15:33:35.048810"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000462, "longitude": -75.000587, "timestamp": "2024-12-11T15:33:35.048810"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000459, "longitude": -75.000527, "timestamp": "2024-12-11T15:33:35.049725"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000485, "longitude": -75.000692, "timestamp": "2024-12-11T15:33:35.050727"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000435, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:35.050727"}
# Sent data from gps_10 (run run_001): {"latitude": 40.00043, "longitude": -75.000642, "timestamp": "2024-12-11T15:33:35.051724"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-11T15:33:35.051724"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 71, "timestamp": "2024-12-11T15:33:35.051724"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000437, "longitude": -75.000642, "timestamp": "2024-12-11T15:33:35.052747"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000436, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:35.052747"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000492, "longitude": -75.000553, "timestamp": "2024-12-11T15:33:35.126965"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000416, "longitude": -75.000548, "timestamp": "2024-12-11T15:33:35.436392"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000454, "longitude": -75.000578, "timestamp": "2024-12-11T15:33:35.436392"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000483, "longitude": -75.000524, "timestamp": "2024-12-11T15:33:35.559884"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000471, "longitude": -75.000586, "timestamp": "2024-12-11T15:33:35.560885"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000431, "longitude": -75.000619, "timestamp": "2024-12-11T15:33:35.560885"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000463, "longitude": -75.000522, "timestamp": "2024-12-11T15:33:35.561900"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000475, "longitude": -75.000701, "timestamp": "2024-12-11T15:33:35.561900"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-11T15:33:35.561900"}
# Sent data from gps_6 (run run_001): {"latitude": 40.00043, "longitude": -75.000651, "timestamp": "2024-12-11T15:33:35.562901"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-11T15:33:35.562901"}
# Sent data from gps_8 (run run_001): {"latitude": 40.00043, "longitude": -75.000611, "timestamp": "2024-12-11T15:33:35.562901"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000437, "longitude": -75.000633, "timestamp": "2024-12-11T15:33:35.562901"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000492, "longitude": -75.000557, "timestamp": "2024-12-11T15:33:35.639910"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000452, "longitude": -75.000566, "timestamp": "2024-12-11T15:33:35.936927"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000417, "longitude": -75.000551, "timestamp": "2024-12-11T15:33:35.936927"}
# Sent data from gps_4 (run run_001): {"latitude": 40.000485, "longitude": -75.000537, "timestamp": "2024-12-11T15:33:36.075797"}
# Sent data from gps_11 (run run_001): {"latitude": 40.000464, "longitude": -75.000592, "timestamp": "2024-12-11T15:33:36.075797"}
# Sent data from gps_10 (run run_001): {"latitude": 40.000434, "longitude": -75.000633, "timestamp": "2024-12-11T15:33:36.075797"}
# Sent data from gps_5 (run run_001): {"latitude": 40.000423, "longitude": -75.000632, "timestamp": "2024-12-11T15:33:36.076797"}
# Sent data from gps_9 (run run_001): {"latitude": 40.000458, "longitude": -75.00052, "timestamp": "2024-12-11T15:33:36.076797"}
# Sent data from gps_6 (run run_001): {"latitude": 40.000437, "longitude": -75.000661, "timestamp": "2024-12-11T15:33:36.076797"}
# Sent data from gps_8 (run run_001): {"latitude": 40.000428, "longitude": -75.000616, "timestamp": "2024-12-11T15:33:36.076797"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 128, "timestamp": "2024-12-11T15:33:36.076797"}
# Sent data from gps_7 (run run_001): {"latitude": 40.000473, "longitude": -75.00071, "timestamp": "2024-12-11T15:33:36.077798"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-11T15:33:36.077798"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000485, "longitude": -75.000544, "timestamp": "2024-12-11T15:33:36.154725"}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 128
#     125     await asyncio.gather(*tasks)
#     127 # Run the main function
# --> 128 await main()
#
# Cell In[6], line 125, in main()
#     118 # Generate tasks for 10 devices of each type
#     119 tasks = [
#     120     *[send_synthetic_data(f"gps_{i}", run_id, "gps") for i in range(1, 12)],
#     121     *[send_synthetic_data(f"player_heart_rate_{i}", run_id, "heart_rate") for i in range(1, 2)],
#     122     *[send_synthetic_data(f"player_temperature_{i}", run_id, "temperature") for i in range(1, 2)]
#     123 ]
# --> 125 await asyncio.gather(*tasks)
#
# Cell In[6], line 113, in send_synthetic_data(device_id, run_id, schema_type)
#     110 print(f"Sent data from {device_id} (run {run_id}): {data_str}")
#     112 message_count += 1
# --> 113 await asyncio.sleep(INTERVAL_SECONDS)
#
# File c:\Python312\Lib\asyncio\tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:
