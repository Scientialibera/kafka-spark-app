# %%
import asyncio
import websockets
import json
import random
import time
from datetime import datetime

# "Magic" Variables
WEBSOCKET_ENDPOINT_TEMPLATE = "ws://localhost:8000/send-stream/{device_id}/{run_id}"
DURATION_SECONDS = 500  # Total duration to send data
INTERVAL_SECONDS = 0.5  # Interval between data sends
OUT_OF_BOUNDS_INTERVAL = 100  # Every 100 messages, send an out-of-bounds message

# GPS-related boundaries and step sizes
PITCH_LAT_MIN = 40.0
PITCH_LAT_MAX = 40.0009
PITCH_LON_MIN = -75.0012
PITCH_LON_MAX = -75.0
STEP_SIZE_LAT = 0.00001  # Latitude step size for random walk (~1 meter)
STEP_SIZE_LON = 0.000015  # Longitude step size for random walk (~1 meter)

# Heart rate boundaries
HR_MIN = 70  # Minimum normal heart rate
HR_MAX = 140  # Maximum normal heart rate
HR_OUT_OF_BOUNDS_LOW = (30, 60)  # Out-of-bounds low range
HR_OUT_OF_BOUNDS_HIGH = (160, 200)  # Out-of-bounds high range

# Temperature boundaries
TEMP_MIN = 36.0  # Minimum normal temperature
TEMP_MAX = 39.0  # Maximum normal temperature
TEMP_OUT_OF_BOUNDS_LOW = (34.0, 35.5)  # Out-of-bounds low range
TEMP_OUT_OF_BOUNDS_HIGH = (39.5, 42.0)  # Out-of-bounds high range

def random_walk(current_lat, current_lon):
    """Perform a random walk within the boundaries of the football pitch."""
    new_lat = current_lat + random.uniform(-STEP_SIZE_LAT, STEP_SIZE_LAT)
    new_lon = current_lon + random.uniform(-STEP_SIZE_LON, STEP_SIZE_LON)
    new_lat = max(min(new_lat, PITCH_LAT_MAX), PITCH_LAT_MIN)
    new_lon = max(min(new_lon, PITCH_LON_MAX), PITCH_LON_MIN)
    return new_lat, new_lon

def generate_heart_rate():
    """Generate a random heart rate between HR_MIN and HR_MAX."""
    return random.randint(HR_MIN, HR_MAX)

def generate_temperature():
    """Generate a random temperature between TEMP_MIN and TEMP_MAX."""
    return round(random.uniform(TEMP_MIN, TEMP_MAX), 1)

async def send_synthetic_data(device_id, run_id, schema_type):
    websocket_endpoint = WEBSOCKET_ENDPOINT_TEMPLATE.format(device_id=device_id, run_id=run_id)

    async with websockets.connect(websocket_endpoint) as websocket:
        start_time = time.time()
        end_time = start_time + DURATION_SECONDS
        current_lat = (PITCH_LAT_MIN + PITCH_LAT_MAX) / 2
        current_lon = (PITCH_LON_MIN + PITCH_LON_MAX) / 2
        message_count = 0

        while time.time() < end_time:
            if schema_type == "gps":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_lat = PITCH_LAT_MAX + random.uniform(0.0001, 0.0005)
                    out_of_bounds_lon = PITCH_LON_MAX + random.uniform(0.0001, 0.0005)
                    data = {
                        "latitude": round(out_of_bounds_lat, 6),
                        "longitude": round(out_of_bounds_lon, 6),
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    current_lat, current_lon = random_walk(current_lat, current_lon)
                    data = {
                        "latitude": round(current_lat, 6),
                        "longitude": round(current_lon, 6),
                        "timestamp": datetime.utcnow().isoformat()
                    }
            elif schema_type == "heart_rate":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_hr = random.choice(
                        [random.randint(*HR_OUT_OF_BOUNDS_LOW), random.randint(*HR_OUT_OF_BOUNDS_HIGH)]
                    )
                    data = {
                        "heart_rate": out_of_bounds_hr,
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    heart_rate = generate_heart_rate()
                    data = {
                        "heart_rate": heart_rate,
                        "timestamp": datetime.utcnow().isoformat()
                    }
            elif schema_type == "temperature":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_temp = random.choice(
                        [round(random.uniform(*TEMP_OUT_OF_BOUNDS_LOW), 1), round(random.uniform(*TEMP_OUT_OF_BOUNDS_HIGH), 1)]
                    )
                    data = {
                        "temperature": out_of_bounds_temp,
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    temperature = generate_temperature()
                    data = {
                        "temperature": temperature,
                        "timestamp": datetime.utcnow().isoformat()
                    }

            data_str = json.dumps(data)
            await websocket.send(data_str)
            print(f"Sent data from {device_id} (run {run_id}): {data_str}")

            message_count += 1
            await asyncio.sleep(INTERVAL_SECONDS)

async def main():
    run_id = "run_001"
    
    # Generate tasks for 10 devices of each type
    tasks = [
        *[send_synthetic_data(f"gps_{i}", run_id, "gps") for i in range(1, 4)],
        *[send_synthetic_data(f"player_heart_rate_{i}", run_id, "heart_rate") for i in range(1, 4)],
        *[send_synthetic_data(f"player_temperature_{i}", run_id, "temperature") for i in range(1, 4)]
    ]
    
    await asyncio.gather(*tasks)

# Run the main function
await main()
# Out:
# Sent data from gps_3 (run run_001): {"latitude": 40.000452, "longitude": -75.000588, "timestamp": "2024-12-12T00:02:56.040646"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000454, "longitude": -75.00061, "timestamp": "2024-12-12T00:02:56.044993"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000454, "longitude": -75.00059, "timestamp": "2024-12-12T00:02:56.054238"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000442, "longitude": -75.000582, "timestamp": "2024-12-12T00:02:56.565865"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000456, "longitude": -75.000619, "timestamp": "2024-12-12T00:02:56.571111"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000447, "longitude": -75.000604, "timestamp": "2024-12-12T00:02:56.572135"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 75, "timestamp": "2024-12-12T00:02:56.709344"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 97, "timestamp": "2024-12-12T00:02:56.714801"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 121, "timestamp": "2024-12-12T00:02:56.716422"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-12T00:02:56.718822"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.5, "timestamp": "2024-12-12T00:02:56.882741"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000447, "longitude": -75.00057, "timestamp": "2024-12-12T00:02:57.079278"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00045, "longitude": -75.000629, "timestamp": "2024-12-12T00:02:57.083346"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000454, "longitude": -75.00061, "timestamp": "2024-12-12T00:02:57.087175"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-12T00:02:57.110275"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 71, "timestamp": "2024-12-12T00:02:57.221071"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 134, "timestamp": "2024-12-12T00:02:57.223343"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:02:57.224884"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 119, "timestamp": "2024-12-12T00:02:57.225435"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-12T00:02:57.392558"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000455, "longitude": -75.000617, "timestamp": "2024-12-12T00:02:57.596989"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000453, "longitude": -75.000572, "timestamp": "2024-12-12T00:02:57.599691"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000455, "longitude": -75.000624, "timestamp": "2024-12-12T00:02:57.600778"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-12T00:02:57.628054"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 129, "timestamp": "2024-12-12T00:02:57.735505"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-12T00:02:57.737339"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 114, "timestamp": "2024-12-12T00:02:57.738416"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-12T00:02:57.738416"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-12T00:02:57.905450"}
# Sent data from gps_2 (run run_001): {"latitude": 40.00046, "longitude": -75.000622, "timestamp": "2024-12-12T00:02:58.110060"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000455, "longitude": -75.000568, "timestamp": "2024-12-12T00:02:58.114227"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000453, "longitude": -75.00062, "timestamp": "2024-12-12T00:02:58.115950"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:02:58.117168"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 125, "timestamp": "2024-12-12T00:02:58.250748"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:02:58.252678"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-12T00:02:58.253828"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 105, "timestamp": "2024-12-12T00:02:58.254967"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:02:58.421253"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-12T00:02:58.625381"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000459, "longitude": -75.000608, "timestamp": "2024-12-12T00:02:58.628380"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000462, "longitude": -75.000561, "timestamp": "2024-12-12T00:02:58.629375"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000466, "longitude": -75.000634, "timestamp": "2024-12-12T00:02:58.629375"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 77, "timestamp": "2024-12-12T00:02:58.764727"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 93, "timestamp": "2024-12-12T00:02:58.767509"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.8, "timestamp": "2024-12-12T00:02:58.767708"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 134, "timestamp": "2024-12-12T00:02:58.769228"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:02:58.939001"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000474, "longitude": -75.000641, "timestamp": "2024-12-12T00:02:59.141748"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000471, "longitude": -75.000559, "timestamp": "2024-12-12T00:02:59.143346"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000456, "longitude": -75.000606, "timestamp": "2024-12-12T00:02:59.143864"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.7, "timestamp": "2024-12-12T00:02:59.143864"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 77, "timestamp": "2024-12-12T00:02:59.281945"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.4, "timestamp": "2024-12-12T00:02:59.284629"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 125, "timestamp": "2024-12-12T00:02:59.286231"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 80, "timestamp": "2024-12-12T00:02:59.287199"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:02:59.451102"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.7, "timestamp": "2024-12-12T00:02:59.654629"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000455, "longitude": -75.000612, "timestamp": "2024-12-12T00:02:59.655756"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000465, "longitude": -75.000571, "timestamp": "2024-12-12T00:02:59.656917"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000472, "longitude": -75.000635, "timestamp": "2024-12-12T00:02:59.657533"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 97, "timestamp": "2024-12-12T00:02:59.793882"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 105, "timestamp": "2024-12-12T00:02:59.794464"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-12T00:02:59.795637"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 75, "timestamp": "2024-12-12T00:02:59.796148"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-12T00:02:59.964623"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000466, "longitude": -75.000648, "timestamp": "2024-12-12T00:03:00.163890"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000465, "longitude": -75.000585, "timestamp": "2024-12-12T00:03:00.164997"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000448, "longitude": -75.000598, "timestamp": "2024-12-12T00:03:00.165562"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-12T00:03:00.165562"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 101, "timestamp": "2024-12-12T00:03:00.301151"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-12T00:03:00.303210"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 88, "timestamp": "2024-12-12T00:03:00.303839"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 107, "timestamp": "2024-12-12T00:03:00.304354"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-12T00:03:00.487422"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000458, "longitude": -75.000596, "timestamp": "2024-12-12T00:03:00.672405"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000453, "longitude": -75.000595, "timestamp": "2024-12-12T00:03:00.675569"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000468, "longitude": -75.000636, "timestamp": "2024-12-12T00:03:00.678102"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-12T00:03:00.679721"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 91, "timestamp": "2024-12-12T00:03:00.812877"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:00.813845"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 96, "timestamp": "2024-12-12T00:03:00.814449"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 114, "timestamp": "2024-12-12T00:03:00.814785"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-12T00:03:01.001309"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-12T00:03:01.188634"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000446, "longitude": -75.000592, "timestamp": "2024-12-12T00:03:01.189688"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000453, "longitude": -75.000592, "timestamp": "2024-12-12T00:03:01.190063"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000469, "longitude": -75.000641, "timestamp": "2024-12-12T00:03:01.190584"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 120, "timestamp": "2024-12-12T00:03:01.329180"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-12T00:03:01.332604"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 121, "timestamp": "2024-12-12T00:03:01.333695"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 95, "timestamp": "2024-12-12T00:03:01.334821"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.7, "timestamp": "2024-12-12T00:03:01.518286"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000477, "longitude": -75.000648, "timestamp": "2024-12-12T00:03:01.704623"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000444, "longitude": -75.000605, "timestamp": "2024-12-12T00:03:01.707715"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000439, "longitude": -75.000584, "timestamp": "2024-12-12T00:03:01.708256"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.5, "timestamp": "2024-12-12T00:03:01.709280"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 99, "timestamp": "2024-12-12T00:03:01.845001"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 79, "timestamp": "2024-12-12T00:03:01.847534"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-12T00:03:01.850471"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 140, "timestamp": "2024-12-12T00:03:01.852242"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:02.019038"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.1, "timestamp": "2024-12-12T00:03:02.223321"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00044, "longitude": -75.000597, "timestamp": "2024-12-12T00:03:02.225319"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000452, "longitude": -75.000593, "timestamp": "2024-12-12T00:03:02.226850"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000472, "longitude": -75.000651, "timestamp": "2024-12-12T00:03:02.228257"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.2, "timestamp": "2024-12-12T00:03:02.346531"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 101, "timestamp": "2024-12-12T00:03:02.347584"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 75, "timestamp": "2024-12-12T00:03:02.348260"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 76, "timestamp": "2024-12-12T00:03:02.377057"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-12T00:03:02.532919"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000453, "longitude": -75.000593, "timestamp": "2024-12-12T00:03:02.733119"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000447, "longitude": -75.000597, "timestamp": "2024-12-12T00:03:02.735348"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.2, "timestamp": "2024-12-12T00:03:02.735920"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000475, "longitude": -75.000636, "timestamp": "2024-12-12T00:03:02.736433"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 91, "timestamp": "2024-12-12T00:03:02.858249"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 131, "timestamp": "2024-12-12T00:03:02.862003"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-12T00:03:02.863728"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 78, "timestamp": "2024-12-12T00:03:02.865033"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:03.044964"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000466, "longitude": -75.000649, "timestamp": "2024-12-12T00:03:03.246837"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:03:03.249545"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000437, "longitude": -75.000598, "timestamp": "2024-12-12T00:03:03.251531"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000448, "longitude": -75.000579, "timestamp": "2024-12-12T00:03:03.252045"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 108, "timestamp": "2024-12-12T00:03:03.368910"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:03:03.370075"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 93, "timestamp": "2024-12-12T00:03:03.371233"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 92, "timestamp": "2024-12-12T00:03:03.372609"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:03:03.555280"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000449, "longitude": -75.000588, "timestamp": "2024-12-12T00:03:03.757482"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000435, "longitude": -75.000586, "timestamp": "2024-12-12T00:03:03.760000"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-12T00:03:03.761574"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000469, "longitude": -75.000635, "timestamp": "2024-12-12T00:03:03.762130"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 79, "timestamp": "2024-12-12T00:03:03.880522"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 110, "timestamp": "2024-12-12T00:03:03.883049"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.8, "timestamp": "2024-12-12T00:03:03.884071"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 105, "timestamp": "2024-12-12T00:03:03.885289"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.5, "timestamp": "2024-12-12T00:03:04.067630"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000465, "longitude": -75.000649, "timestamp": "2024-12-12T00:03:04.289223"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-12T00:03:04.292293"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000441, "longitude": -75.000586, "timestamp": "2024-12-12T00:03:04.293861"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000454, "longitude": -75.000586, "timestamp": "2024-12-12T00:03:04.295032"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 78, "timestamp": "2024-12-12T00:03:04.378811"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 140, "timestamp": "2024-12-12T00:03:04.380882"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 112, "timestamp": "2024-12-12T00:03:04.409703"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.2, "timestamp": "2024-12-12T00:03:04.411956"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.8, "timestamp": "2024-12-12T00:03:04.580482"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000446, "longitude": -75.000589, "timestamp": "2024-12-12T00:03:04.813108"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.2, "timestamp": "2024-12-12T00:03:04.816365"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000473, "longitude": -75.000639, "timestamp": "2024-12-12T00:03:04.816881"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000451, "longitude": -75.000593, "timestamp": "2024-12-12T00:03:04.818906"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 139, "timestamp": "2024-12-12T00:03:04.890090"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 101, "timestamp": "2024-12-12T00:03:04.891455"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-12T00:03:04.921337"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 89, "timestamp": "2024-12-12T00:03:04.923336"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-12T00:03:05.095012"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000459, "longitude": -75.000598, "timestamp": "2024-12-12T00:03:05.324690"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000465, "longitude": -75.000649, "timestamp": "2024-12-12T00:03:05.329386"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.0, "timestamp": "2024-12-12T00:03:05.330934"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000456, "longitude": -75.000585, "timestamp": "2024-12-12T00:03:05.332029"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 135, "timestamp": "2024-12-12T00:03:05.403017"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 73, "timestamp": "2024-12-12T00:03:05.404012"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-12T00:03:05.404490"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 97, "timestamp": "2024-12-12T00:03:05.405332"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-12T00:03:05.607892"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:03:05.841450"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000462, "longitude": -75.000636, "timestamp": "2024-12-12T00:03:05.843753"}
# Sent data from gps_3 (run run_001): {"latitude": 40.00046, "longitude": -75.000609, "timestamp": "2024-12-12T00:03:05.844553"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000449, "longitude": -75.000583, "timestamp": "2024-12-12T00:03:05.845317"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 85, "timestamp": "2024-12-12T00:03:05.919395"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 128, "timestamp": "2024-12-12T00:03:05.920791"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-12T00:03:05.921519"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-12T00:03:05.922124"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.8, "timestamp": "2024-12-12T00:03:06.121875"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-12T00:03:06.353383"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000458, "longitude": -75.000585, "timestamp": "2024-12-12T00:03:06.354624"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000466, "longitude": -75.000596, "timestamp": "2024-12-12T00:03:06.355338"}
# Sent data from gps_2 (run run_001): {"latitude": 40.00046, "longitude": -75.000634, "timestamp": "2024-12-12T00:03:06.355655"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 96, "timestamp": "2024-12-12T00:03:06.429184"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.9, "timestamp": "2024-12-12T00:03:06.431609"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 98, "timestamp": "2024-12-12T00:03:06.432841"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 78, "timestamp": "2024-12-12T00:03:06.434584"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-12T00:03:06.629140"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-12T00:03:06.878966"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000452, "longitude": -75.000635, "timestamp": "2024-12-12T00:03:06.881065"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000465, "longitude": -75.000574, "timestamp": "2024-12-12T00:03:06.881065"}
# Sent data from gps_3 (run run_001): {"latitude": 40.00047, "longitude": -75.000605, "timestamp": "2024-12-12T00:03:06.882413"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 106, "timestamp": "2024-12-12T00:03:06.941148"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 91, "timestamp": "2024-12-12T00:03:06.943149"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 102, "timestamp": "2024-12-12T00:03:06.943706"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.1, "timestamp": "2024-12-12T00:03:06.944655"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-12T00:03:07.146560"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:03:07.394513"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000461, "longitude": -75.000593, "timestamp": "2024-12-12T00:03:07.396536"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000459, "longitude": -75.000644, "timestamp": "2024-12-12T00:03:07.398556"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000458, "longitude": -75.000564, "timestamp": "2024-12-12T00:03:07.399563"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 105, "timestamp": "2024-12-12T00:03:07.457431"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:03:07.458592"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 139, "timestamp": "2024-12-12T00:03:07.459507"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 78, "timestamp": "2024-12-12T00:03:07.460086"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.9, "timestamp": "2024-12-12T00:03:07.658665"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-12T00:03:07.906928"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000461, "longitude": -75.000555, "timestamp": "2024-12-12T00:03:07.908348"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000465, "longitude": -75.000586, "timestamp": "2024-12-12T00:03:07.909467"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000468, "longitude": -75.000635, "timestamp": "2024-12-12T00:03:07.909978"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 95, "timestamp": "2024-12-12T00:03:07.968845"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-12T00:03:07.969884"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 139, "timestamp": "2024-12-12T00:03:07.970564"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:03:07.971078"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.4, "timestamp": "2024-12-12T00:03:08.171282"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.1, "timestamp": "2024-12-12T00:03:08.420070"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000471, "longitude": -75.000633, "timestamp": "2024-12-12T00:03:08.421808"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000462, "longitude": -75.000555, "timestamp": "2024-12-12T00:03:08.423763"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000465, "longitude": -75.000598, "timestamp": "2024-12-12T00:03:08.424382"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 133, "timestamp": "2024-12-12T00:03:08.483796"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:08.484935"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-12T00:03:08.486248"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-12T00:03:08.487386"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:03:08.687127"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-12T00:03:08.936162"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000459, "longitude": -75.000587, "timestamp": "2024-12-12T00:03:08.940596"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000469, "longitude": -75.000619, "timestamp": "2024-12-12T00:03:08.943030"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000468, "longitude": -75.000562, "timestamp": "2024-12-12T00:03:08.944935"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 84, "timestamp": "2024-12-12T00:03:08.998806"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 117, "timestamp": "2024-12-12T00:03:09.000002"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 115, "timestamp": "2024-12-12T00:03:09.001248"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-12T00:03:09.001761"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-12T00:03:09.199736"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.3, "timestamp": "2024-12-12T00:03:09.449685"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000468, "longitude": -75.000573, "timestamp": "2024-12-12T00:03:09.451632"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000455, "longitude": -75.0006, "timestamp": "2024-12-12T00:03:09.452501"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000469, "longitude": -75.000619, "timestamp": "2024-12-12T00:03:09.452824"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 79, "timestamp": "2024-12-12T00:03:09.511969"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-12T00:03:09.513970"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 135, "timestamp": "2024-12-12T00:03:09.514972"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 119, "timestamp": "2024-12-12T00:03:09.515964"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.2, "timestamp": "2024-12-12T00:03:09.715766"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-12T00:03:09.964696"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000472, "longitude": -75.000616, "timestamp": "2024-12-12T00:03:09.966751"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000473, "longitude": -75.000563, "timestamp": "2024-12-12T00:03:09.966751"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000453, "longitude": -75.000596, "timestamp": "2024-12-12T00:03:09.967766"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 72, "timestamp": "2024-12-12T00:03:10.025977"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 118, "timestamp": "2024-12-12T00:03:10.027113"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 89, "timestamp": "2024-12-12T00:03:10.027633"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:10.027633"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-12T00:03:10.227810"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-12T00:03:10.474738"}
# Sent data from gps_3 (run run_001): {"latitude": 40.00045, "longitude": -75.000582, "timestamp": "2024-12-12T00:03:10.477734"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000467, "longitude": -75.000614, "timestamp": "2024-12-12T00:03:10.479315"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000483, "longitude": -75.000576, "timestamp": "2024-12-12T00:03:10.481158"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 134, "timestamp": "2024-12-12T00:03:10.536137"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:03:10.537229"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-12T00:03:10.537229"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 89, "timestamp": "2024-12-12T00:03:10.538070"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-12T00:03:10.756269"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.8, "timestamp": "2024-12-12T00:03:10.991165"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000476, "longitude": -75.000584, "timestamp": "2024-12-12T00:03:10.994350"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000442, "longitude": -75.000569, "timestamp": "2024-12-12T00:03:10.995901"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000467, "longitude": -75.000617, "timestamp": "2024-12-12T00:03:10.996428"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 109, "timestamp": "2024-12-12T00:03:11.038266"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 135, "timestamp": "2024-12-12T00:03:11.039262"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 104, "timestamp": "2024-12-12T00:03:11.040262"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-12T00:03:11.041129"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:11.256624"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:11.522856"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000458, "longitude": -75.00061, "timestamp": "2024-12-12T00:03:11.525944"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000476, "longitude": -75.000588, "timestamp": "2024-12-12T00:03:11.527100"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000434, "longitude": -75.000555, "timestamp": "2024-12-12T00:03:11.527613"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 101, "timestamp": "2024-12-12T00:03:11.528259"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 128, "timestamp": "2024-12-12T00:03:11.528773"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 85, "timestamp": "2024-12-12T00:03:11.529271"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-12T00:03:11.529936"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.2, "timestamp": "2024-12-12T00:03:11.755956"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-12T00:03:12.039147"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 135, "timestamp": "2024-12-12T00:03:12.041111"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000442, "longitude": -75.000549, "timestamp": "2024-12-12T00:03:12.043208"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000473, "longitude": -75.000575, "timestamp": "2024-12-12T00:03:12.045621"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-12T00:03:12.046641"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 80, "timestamp": "2024-12-12T00:03:12.048220"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 81, "timestamp": "2024-12-12T00:03:12.048734"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000465, "longitude": -75.000613, "timestamp": "2024-12-12T00:03:12.048734"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-12T00:03:12.273014"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:12.552814"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 140, "timestamp": "2024-12-12T00:03:12.554469"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000482, "longitude": -75.000572, "timestamp": "2024-12-12T00:03:12.555802"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:12.556364"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000452, "longitude": -75.000536, "timestamp": "2024-12-12T00:03:12.556975"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 84, "timestamp": "2024-12-12T00:03:12.557565"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000473, "longitude": -75.000621, "timestamp": "2024-12-12T00:03:12.558091"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 103, "timestamp": "2024-12-12T00:03:12.558239"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-12T00:03:12.770497"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 99, "timestamp": "2024-12-12T00:03:13.066028"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000485, "longitude": -75.00058, "timestamp": "2024-12-12T00:03:13.068023"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-12T00:03:13.069017"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-12T00:03:13.070398"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000451, "longitude": -75.000539, "timestamp": "2024-12-12T00:03:13.071010"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 97, "timestamp": "2024-12-12T00:03:13.071585"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 125, "timestamp": "2024-12-12T00:03:13.072268"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000465, "longitude": -75.000611, "timestamp": "2024-12-12T00:03:13.072841"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:13.269607"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000492, "longitude": -75.000576, "timestamp": "2024-12-12T00:03:13.581601"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-12T00:03:13.583216"}
# Sent data from gps_3 (run run_001): {"latitude": 40.00045, "longitude": -75.000547, "timestamp": "2024-12-12T00:03:13.583763"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-12T00:03:13.584312"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 119, "timestamp": "2024-12-12T00:03:13.584387"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 80, "timestamp": "2024-12-12T00:03:13.584976"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 73, "timestamp": "2024-12-12T00:03:13.585489"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000463, "longitude": -75.000613, "timestamp": "2024-12-12T00:03:13.585489"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.0, "timestamp": "2024-12-12T00:03:13.783970"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.4, "timestamp": "2024-12-12T00:03:14.097138"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:14.098170"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 115, "timestamp": "2024-12-12T00:03:14.098682"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000454, "longitude": -75.000547, "timestamp": "2024-12-12T00:03:14.099682"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000495, "longitude": -75.000575, "timestamp": "2024-12-12T00:03:14.100194"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 99, "timestamp": "2024-12-12T00:03:14.100194"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000472, "longitude": -75.000625, "timestamp": "2024-12-12T00:03:14.100831"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 100, "timestamp": "2024-12-12T00:03:14.101354"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:03:14.297977"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.9, "timestamp": "2024-12-12T00:03:14.606644"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000463, "longitude": -75.000558, "timestamp": "2024-12-12T00:03:14.607378"}
# Sent data from gps_1 (run run_001): {"latitude": 40.0005, "longitude": -75.000575, "timestamp": "2024-12-12T00:03:14.608438"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 132, "timestamp": "2024-12-12T00:03:14.608952"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-12T00:03:14.609015"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 93, "timestamp": "2024-12-12T00:03:14.609015"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 78, "timestamp": "2024-12-12T00:03:14.609597"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000476, "longitude": -75.000639, "timestamp": "2024-12-12T00:03:14.609597"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.1, "timestamp": "2024-12-12T00:03:14.807318"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000458, "longitude": -75.00057, "timestamp": "2024-12-12T00:03:15.106026"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 81, "timestamp": "2024-12-12T00:03:15.107372"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-12T00:03:15.107903"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000498, "longitude": -75.000565, "timestamp": "2024-12-12T00:03:15.107903"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-12T00:03:15.108460"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 82, "timestamp": "2024-12-12T00:03:15.108637"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000484, "longitude": -75.00064, "timestamp": "2024-12-12T00:03:15.108637"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 114, "timestamp": "2024-12-12T00:03:15.109257"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-12T00:03:15.322980"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 124, "timestamp": "2024-12-12T00:03:15.620206"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000502, "longitude": -75.000569, "timestamp": "2024-12-12T00:03:15.623324"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.3, "timestamp": "2024-12-12T00:03:15.624507"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.9, "timestamp": "2024-12-12T00:03:15.624507"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000463, "longitude": -75.000574, "timestamp": "2024-12-12T00:03:15.625020"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 85, "timestamp": "2024-12-12T00:03:15.625407"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 134, "timestamp": "2024-12-12T00:03:15.626017"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000482, "longitude": -75.000626, "timestamp": "2024-12-12T00:03:15.626017"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:15.839340"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.7, "timestamp": "2024-12-12T00:03:16.134637"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000473, "longitude": -75.000589, "timestamp": "2024-12-12T00:03:16.136345"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000502, "longitude": -75.000562, "timestamp": "2024-12-12T00:03:16.137681"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-12T00:03:16.138280"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 116, "timestamp": "2024-12-12T00:03:16.138852"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-12T00:03:16.139363"}
# Sent data from gps_2 (run run_001): {"latitude": 40.00048, "longitude": -75.000627, "timestamp": "2024-12-12T00:03:16.140194"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 109, "timestamp": "2024-12-12T00:03:16.140761"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.3, "timestamp": "2024-12-12T00:03:16.351985"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:16.659880"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000478, "longitude": -75.00058, "timestamp": "2024-12-12T00:03:16.660448"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000497, "longitude": -75.000573, "timestamp": "2024-12-12T00:03:16.661984"}
# Sent data from gps_2 (run run_001): {"latitude": 40.00048, "longitude": -75.000616, "timestamp": "2024-12-12T00:03:16.662591"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 123, "timestamp": "2024-12-12T00:03:16.663103"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 140, "timestamp": "2024-12-12T00:03:16.663223"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.7, "timestamp": "2024-12-12T00:03:16.663855"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 135, "timestamp": "2024-12-12T00:03:16.663855"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.9, "timestamp": "2024-12-12T00:03:16.858590"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000471, "longitude": -75.000579, "timestamp": "2024-12-12T00:03:17.167794"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 95, "timestamp": "2024-12-12T00:03:17.168421"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 85, "timestamp": "2024-12-12T00:03:17.168421"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-12T00:03:17.169026"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-12T00:03:17.169599"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 79, "timestamp": "2024-12-12T00:03:17.169599"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000498, "longitude": -75.000586, "timestamp": "2024-12-12T00:03:17.170167"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000484, "longitude": -75.000627, "timestamp": "2024-12-12T00:03:17.170167"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-12T00:03:17.366536"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-12T00:03:17.688270"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 84, "timestamp": "2024-12-12T00:03:17.688858"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000505, "longitude": -75.000587, "timestamp": "2024-12-12T00:03:17.689421"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000476, "longitude": -75.000613, "timestamp": "2024-12-12T00:03:17.689634"}
# Sent data from gps_3 (run run_001): {"latitude": 40.00048, "longitude": -75.000594, "timestamp": "2024-12-12T00:03:17.690098"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 140, "timestamp": "2024-12-12T00:03:17.690098"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 96, "timestamp": "2024-12-12T00:03:17.690448"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-12T00:03:17.690853"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.9, "timestamp": "2024-12-12T00:03:17.876944"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000487, "longitude": -75.000593, "timestamp": "2024-12-12T00:03:18.203952"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 107, "timestamp": "2024-12-12T00:03:18.204635"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 111, "timestamp": "2024-12-12T00:03:18.204635"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-12T00:03:18.205492"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.5, "timestamp": "2024-12-12T00:03:18.205492"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 84, "timestamp": "2024-12-12T00:03:18.206177"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000496, "longitude": -75.000573, "timestamp": "2024-12-12T00:03:18.206177"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000473, "longitude": -75.000608, "timestamp": "2024-12-12T00:03:18.206177"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-12T00:03:18.389468"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-12T00:03:18.711976"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 101, "timestamp": "2024-12-12T00:03:18.712485"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000488, "longitude": -75.000578, "timestamp": "2024-12-12T00:03:18.713537"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000478, "longitude": -75.000608, "timestamp": "2024-12-12T00:03:18.713537"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000486, "longitude": -75.000605, "timestamp": "2024-12-12T00:03:18.714050"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-12T00:03:18.714256"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 116, "timestamp": "2024-12-12T00:03:18.714256"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-12T00:03:18.714764"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:18.898531"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-12T00:03:19.226897"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000488, "longitude": -75.000607, "timestamp": "2024-12-12T00:03:19.227404"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 92, "timestamp": "2024-12-12T00:03:19.227947"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 95, "timestamp": "2024-12-12T00:03:19.228325"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 119, "timestamp": "2024-12-12T00:03:19.228325"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000496, "longitude": -75.000584, "timestamp": "2024-12-12T00:03:19.229003"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000474, "longitude": -75.000618, "timestamp": "2024-12-12T00:03:19.229756"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-12T00:03:19.229756"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-12T00:03:19.396994"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.7, "timestamp": "2024-12-12T00:03:19.739148"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000492, "longitude": -75.000597, "timestamp": "2024-12-12T00:03:19.739765"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 78, "timestamp": "2024-12-12T00:03:19.740273"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 122, "timestamp": "2024-12-12T00:03:19.740417"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 76, "timestamp": "2024-12-12T00:03:19.740417"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000504, "longitude": -75.000572, "timestamp": "2024-12-12T00:03:19.740417"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000475, "longitude": -75.000627, "timestamp": "2024-12-12T00:03:19.740417"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-12T00:03:19.740923"}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In [1], line 113, in send_synthetic_data(device_id, run_id, schema_type)
#     112 message_count += 1
# --> 113 await asyncio.sleep(INTERVAL_SECONDS)
#
# File c:\Users\emilio.arzamendi\AppData\Local\Programs\Python\Python39\lib\asyncio\tasks.py:652, in sleep(delay, result, loop)
#     651 try:
# --> 652     return await future
#     653 finally:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In [1], line 128
#     125     await asyncio.gather(*tasks)
#     127 # Run the main function
# --> 128 await main()
#
# Cell In [1], line 125, in main()
#     118 # Generate tasks for 10 devices of each type
#     119 tasks = [
#     120     *[send_synthetic_data(f"gps_{i}", run_id, "gps") for i in range(1, 4)],
#     121     *[send_synthetic_data(f"player_heart_rate_{i}", run_id, "heart_rate") for i in range(1, 4)],
#     122     *[send_synthetic_data(f"player_temperature_{i}", run_id, "temperature") for i in range(1, 4)]
#     123 ]
# --> 125 await asyncio.gather(*tasks)
#
# CancelledError:
