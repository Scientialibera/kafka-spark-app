# %%
import requests

# Define the URL of the FastAPI endpoint
url = "http://127.0.0.1:8000/register-device"

# Define the schemas for different device types
schemas = {
    "gps": {
        "latitude": "float",
        "longitude": "float",
        "timestamp": "string"
    },
    "accel": {
        "acceleration_x": "float",
        "acceleration_y": "float",
        "acceleration_z": "float",
        "timestamp": "string"
    },
    "wind": {
        "speed": "float",
        "direction": "float",
        "timestamp": "string"
    },
    "player_temperature": {
        "temperature": "float",
        "timestamp": "string"
    },
    "player_heart_rate": {
        "heart_rate": "int",
        "timestamp": "string"
    }
}

# Number of devices to register for each type
num_devices = 10

# Loop through each device type and create multiple devices
for device_type, schema in schemas.items():
    for i in range(2, num_devices + 2):  # Starts at 2, ends at 11 (10 devices)
        device_name = f"{device_type}_{i}"
        payload = {
            "device_name": device_name,
            "schema": schema
        }
        
        # Send POST request to register the device
        response = requests.post(url, json=payload)
        
        # Print the status code and response for each device
        print(f"Registering device: {device_name}")
        print(f"Status Code: {response.status_code}")
        try:
            print(f"Response JSON: {response.json()}\n")
        except Exception as e:
            print(f"Error parsing response for {device_name}: {e}\n")

# %%
import asyncio
import websockets
import json
import random
import time
from datetime import datetime

# "Magic" Variables
WEBSOCKET_ENDPOINT_TEMPLATE = "ws://localhost:8000/send-stream/{device_id}/{run_id}"
DURATION_SECONDS = 500  # Total duration to send data
INTERVAL_SECONDS = 0.5  # Interval between data sends
OUT_OF_BOUNDS_INTERVAL = 100  # Every 100 messages, send an out-of-bounds message

# GPS-related boundaries and step sizes
PITCH_LAT_MIN = 40.0
PITCH_LAT_MAX = 40.0009
PITCH_LON_MIN = -75.0012
PITCH_LON_MAX = -75.0
STEP_SIZE_LAT = 0.00001  # Latitude step size for random walk (~1 meter)
STEP_SIZE_LON = 0.000015  # Longitude step size for random walk (~1 meter)

# Heart rate boundaries
HR_MIN = 70  # Minimum normal heart rate
HR_MAX = 140  # Maximum normal heart rate
HR_OUT_OF_BOUNDS_LOW = (30, 60)  # Out-of-bounds low range
HR_OUT_OF_BOUNDS_HIGH = (160, 200)  # Out-of-bounds high range

# Temperature boundaries
TEMP_MIN = 36.0  # Minimum normal temperature
TEMP_MAX = 39.0  # Maximum normal temperature
TEMP_OUT_OF_BOUNDS_LOW = (34.0, 35.5)  # Out-of-bounds low range
TEMP_OUT_OF_BOUNDS_HIGH = (39.5, 42.0)  # Out-of-bounds high range

def random_walk(current_lat, current_lon):
    """Perform a random walk within the boundaries of the football pitch."""
    new_lat = current_lat + random.uniform(-STEP_SIZE_LAT, STEP_SIZE_LAT)
    new_lon = current_lon + random.uniform(-STEP_SIZE_LON, STEP_SIZE_LON)
    new_lat = max(min(new_lat, PITCH_LAT_MAX), PITCH_LAT_MIN)
    new_lon = max(min(new_lon, PITCH_LON_MAX), PITCH_LON_MIN)
    return new_lat, new_lon

def generate_heart_rate():
    """Generate a random heart rate between HR_MIN and HR_MAX."""
    return random.randint(HR_MIN, HR_MAX)

def generate_temperature():
    """Generate a random temperature between TEMP_MIN and TEMP_MAX."""
    return round(random.uniform(TEMP_MIN, TEMP_MAX), 1)

async def send_synthetic_data(device_id, run_id, schema_type):
    websocket_endpoint = WEBSOCKET_ENDPOINT_TEMPLATE.format(device_id=device_id, run_id=run_id)

    async with websockets.connect(websocket_endpoint) as websocket:
        start_time = time.time()
        end_time = start_time + DURATION_SECONDS
        current_lat = (PITCH_LAT_MIN + PITCH_LAT_MAX) / 2
        current_lon = (PITCH_LON_MIN + PITCH_LON_MAX) / 2
        message_count = 0

        while time.time() < end_time:
            if schema_type == "gps":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_lat = PITCH_LAT_MAX + random.uniform(0.0001, 0.0005)
                    out_of_bounds_lon = PITCH_LON_MAX + random.uniform(0.0001, 0.0005)
                    data = {
                        "latitude": round(out_of_bounds_lat, 6),
                        "longitude": round(out_of_bounds_lon, 6),
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    current_lat, current_lon = random_walk(current_lat, current_lon)
                    data = {
                        "latitude": round(current_lat, 6),
                        "longitude": round(current_lon, 6),
                        "timestamp": datetime.utcnow().isoformat()
                    }
            elif schema_type == "heart_rate":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_hr = random.choice(
                        [random.randint(*HR_OUT_OF_BOUNDS_LOW), random.randint(*HR_OUT_OF_BOUNDS_HIGH)]
                    )
                    data = {
                        "heart_rate": out_of_bounds_hr,
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    heart_rate = generate_heart_rate()
                    data = {
                        "heart_rate": heart_rate,
                        "timestamp": datetime.utcnow().isoformat()
                    }
            elif schema_type == "temperature":
                if message_count % OUT_OF_BOUNDS_INTERVAL == 0 and message_count > 0:
                    out_of_bounds_temp = random.choice(
                        [round(random.uniform(*TEMP_OUT_OF_BOUNDS_LOW), 1), round(random.uniform(*TEMP_OUT_OF_BOUNDS_HIGH), 1)]
                    )
                    data = {
                        "temperature": out_of_bounds_temp,
                        "timestamp": datetime.utcnow().isoformat()
                    }
                else:
                    temperature = generate_temperature()
                    data = {
                        "temperature": temperature,
                        "timestamp": datetime.utcnow().isoformat()
                    }

            data_str = json.dumps(data)
            await websocket.send(data_str)
            print(f"Sent data from {device_id} (run {run_id}): {data_str}")

            message_count += 1
            await asyncio.sleep(INTERVAL_SECONDS)

async def main():
    run_id = "run_001"
    
    # Generate tasks for 10 devices of each type
    tasks = [
        *[send_synthetic_data(f"gps_{i}", run_id, "gps") for i in range(1, 4)],
        *[send_synthetic_data(f"player_heart_rate_{i}", run_id, "heart_rate") for i in range(1, 4)],
        *[send_synthetic_data(f"player_temperature_{i}", run_id, "temperature") for i in range(1, 4)]
    ]
    
    await asyncio.gather(*tasks)

# Run the main function
await main()
# Out:
# Sent data from gps_2 (run run_001): {"latitude": 40.000448, "longitude": -75.000588, "timestamp": "2024-12-10T12:55:03.487836"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000454, "longitude": -75.00061, "timestamp": "2024-12-10T12:55:03.940682"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 72, "timestamp": "2024-12-10T12:55:03.941937"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000459, "longitude": -75.000597, "timestamp": "2024-12-10T12:55:03.941937"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-10T12:55:03.942604"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000443, "longitude": -75.000593, "timestamp": "2024-12-10T12:55:03.998207"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 98, "timestamp": "2024-12-10T12:55:04.177049"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-10T12:55:04.178034"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000457, "longitude": -75.000601, "timestamp": "2024-12-10T12:55:04.451438"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 76, "timestamp": "2024-12-10T12:55:04.451438"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000469, "longitude": -75.000596, "timestamp": "2024-12-10T12:55:04.452415"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.7, "timestamp": "2024-12-10T12:55:04.452415"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000442, "longitude": -75.000596, "timestamp": "2024-12-10T12:55:04.513645"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 101, "timestamp": "2024-12-10T12:55:04.551681"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 85, "timestamp": "2024-12-10T12:55:04.687613"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.1, "timestamp": "2024-12-10T12:55:04.687613"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-10T12:55:04.736635"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000476, "longitude": -75.00059, "timestamp": "2024-12-10T12:55:04.967692"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-10T12:55:04.967692"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000462, "longitude": -75.000611, "timestamp": "2024-12-10T12:55:04.968657"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 85, "timestamp": "2024-12-10T12:55:04.968657"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000442, "longitude": -75.000609, "timestamp": "2024-12-10T12:55:05.030225"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 109, "timestamp": "2024-12-10T12:55:05.060745"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-10T12:55:05.200357"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.5, "timestamp": "2024-12-10T12:55:05.200357"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-10T12:55:05.247503"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000465, "longitude": -75.000608, "timestamp": "2024-12-10T12:55:05.483389"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-10T12:55:05.483389"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 103, "timestamp": "2024-12-10T12:55:05.484347"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000483, "longitude": -75.000583, "timestamp": "2024-12-10T12:55:05.484347"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000442, "longitude": -75.000623, "timestamp": "2024-12-10T12:55:05.546333"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 136, "timestamp": "2024-12-10T12:55:05.546333"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 97, "timestamp": "2024-12-10T12:55:05.701787"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-10T12:55:05.701787"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.7, "timestamp": "2024-12-10T12:55:05.748624"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 76, "timestamp": "2024-12-10T12:55:05.984234"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.8, "timestamp": "2024-12-10T12:55:05.984893"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00048, "longitude": -75.000585, "timestamp": "2024-12-10T12:55:05.984893"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000474, "longitude": -75.000609, "timestamp": "2024-12-10T12:55:05.984893"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000442, "longitude": -75.000625, "timestamp": "2024-12-10T12:55:06.061825"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 81, "timestamp": "2024-12-10T12:55:06.062460"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-10T12:55:06.217723"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-10T12:55:06.217723"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-10T12:55:06.264246"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000471, "longitude": -75.00059, "timestamp": "2024-12-10T12:55:06.483960"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-10T12:55:06.483960"}
# Sent data from gps_3 (run run_001): {"latitude": 40.00048, "longitude": -75.000612, "timestamp": "2024-12-10T12:55:06.483960"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 109, "timestamp": "2024-12-10T12:55:06.484962"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000443, "longitude": -75.000611, "timestamp": "2024-12-10T12:55:06.577655"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 110, "timestamp": "2024-12-10T12:55:06.577655"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 90, "timestamp": "2024-12-10T12:55:06.719078"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.8, "timestamp": "2024-12-10T12:55:06.719078"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-10T12:55:06.780952"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000482, "longitude": -75.0006, "timestamp": "2024-12-10T12:55:06.984621"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-10T12:55:06.984621"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 121, "timestamp": "2024-12-10T12:55:06.985246"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000474, "longitude": -75.000583, "timestamp": "2024-12-10T12:55:06.985246"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000437, "longitude": -75.000605, "timestamp": "2024-12-10T12:55:07.093798"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 94, "timestamp": "2024-12-10T12:55:07.093798"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 71, "timestamp": "2024-12-10T12:55:07.233148"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-10T12:55:07.233148"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-10T12:55:07.295683"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 101, "timestamp": "2024-12-10T12:55:07.497314"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.7, "timestamp": "2024-12-10T12:55:07.497314"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000481, "longitude": -75.000596, "timestamp": "2024-12-10T12:55:07.498313"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000472, "longitude": -75.000606, "timestamp": "2024-12-10T12:55:07.498313"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000427, "longitude": -75.000594, "timestamp": "2024-12-10T12:55:07.607498"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 127, "timestamp": "2024-12-10T12:55:07.607498"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 121, "timestamp": "2024-12-10T12:55:07.733280"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.6, "timestamp": "2024-12-10T12:55:07.733849"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-10T12:55:07.812173"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 88, "timestamp": "2024-12-10T12:55:07.999259"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000489, "longitude": -75.000584, "timestamp": "2024-12-10T12:55:07.999259"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-10T12:55:07.999259"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000472, "longitude": -75.000593, "timestamp": "2024-12-10T12:55:07.999259"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000427, "longitude": -75.000606, "timestamp": "2024-12-10T12:55:08.108395"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 102, "timestamp": "2024-12-10T12:55:08.108395"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 93, "timestamp": "2024-12-10T12:55:08.248444"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 39.0, "timestamp": "2024-12-10T12:55:08.249251"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-10T12:55:08.327252"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.7, "timestamp": "2024-12-10T12:55:08.499722"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000484, "longitude": -75.000593, "timestamp": "2024-12-10T12:55:08.499722"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000473, "longitude": -75.000602, "timestamp": "2024-12-10T12:55:08.500721"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 109, "timestamp": "2024-12-10T12:55:08.500721"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000423, "longitude": -75.000618, "timestamp": "2024-12-10T12:55:08.625182"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 88, "timestamp": "2024-12-10T12:55:08.625182"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 77, "timestamp": "2024-12-10T12:55:08.765183"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.1, "timestamp": "2024-12-10T12:55:08.765183"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-10T12:55:08.843959"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000477, "longitude": -75.000599, "timestamp": "2024-12-10T12:55:09.000145"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000478, "longitude": -75.000581, "timestamp": "2024-12-10T12:55:09.000145"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 126, "timestamp": "2024-12-10T12:55:09.001129"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-10T12:55:09.001129"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000422, "longitude": -75.000608, "timestamp": "2024-12-10T12:55:09.127446"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 71, "timestamp": "2024-12-10T12:55:09.127446"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 137, "timestamp": "2024-12-10T12:55:09.267738"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-10T12:55:09.268310"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.0, "timestamp": "2024-12-10T12:55:09.348462"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 136, "timestamp": "2024-12-10T12:55:09.504959"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000476, "longitude": -75.000595, "timestamp": "2024-12-10T12:55:09.504959"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-10T12:55:09.505959"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000478, "longitude": -75.000602, "timestamp": "2024-12-10T12:55:09.505959"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000425, "longitude": -75.000608, "timestamp": "2024-12-10T12:55:09.645901"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 96, "timestamp": "2024-12-10T12:55:09.645901"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 114, "timestamp": "2024-12-10T12:55:09.785971"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-10T12:55:09.786626"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.9, "timestamp": "2024-12-10T12:55:09.865020"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.8, "timestamp": "2024-12-10T12:55:10.020871"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000479, "longitude": -75.000596, "timestamp": "2024-12-10T12:55:10.020871"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000487, "longitude": -75.000605, "timestamp": "2024-12-10T12:55:10.021873"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 88, "timestamp": "2024-12-10T12:55:10.021873"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000427, "longitude": -75.000611, "timestamp": "2024-12-10T12:55:10.146983"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 118, "timestamp": "2024-12-10T12:55:10.147595"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 104, "timestamp": "2024-12-10T12:55:10.304111"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.1, "timestamp": "2024-12-10T12:55:10.305115"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.3, "timestamp": "2024-12-10T12:55:10.382025"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000483, "longitude": -75.000607, "timestamp": "2024-12-10T12:55:10.522272"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000473, "longitude": -75.000596, "timestamp": "2024-12-10T12:55:10.523122"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 83, "timestamp": "2024-12-10T12:55:10.523122"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-10T12:55:10.523122"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000423, "longitude": -75.000604, "timestamp": "2024-12-10T12:55:10.663642"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 123, "timestamp": "2024-12-10T12:55:10.663642"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 77, "timestamp": "2024-12-10T12:55:10.818780"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-10T12:55:10.818780"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.0, "timestamp": "2024-12-10T12:55:10.896141"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 95, "timestamp": "2024-12-10T12:55:11.036694"}
# Sent data from gps_1 (run run_001): {"latitude": 40.00048, "longitude": -75.000583, "timestamp": "2024-12-10T12:55:11.036694"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.2, "timestamp": "2024-12-10T12:55:11.037697"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000477, "longitude": -75.000614, "timestamp": "2024-12-10T12:55:11.037697"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000419, "longitude": -75.000606, "timestamp": "2024-12-10T12:55:11.163550"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 79, "timestamp": "2024-12-10T12:55:11.163550"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 90, "timestamp": "2024-12-10T12:55:11.335011"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.9, "timestamp": "2024-12-10T12:55:11.335604"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.5, "timestamp": "2024-12-10T12:55:11.411702"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.7, "timestamp": "2024-12-10T12:55:11.552716"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000488, "longitude": -75.000583, "timestamp": "2024-12-10T12:55:11.553328"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000469, "longitude": -75.000623, "timestamp": "2024-12-10T12:55:11.553328"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 91, "timestamp": "2024-12-10T12:55:11.553328"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000425, "longitude": -75.000591, "timestamp": "2024-12-10T12:55:11.677263"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 117, "timestamp": "2024-12-10T12:55:11.677858"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 80, "timestamp": "2024-12-10T12:55:11.849211"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.1, "timestamp": "2024-12-10T12:55:11.849211"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 37.4, "timestamp": "2024-12-10T12:55:11.912280"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-10T12:55:12.053729"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 118, "timestamp": "2024-12-10T12:55:12.054724"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000471, "longitude": -75.000613, "timestamp": "2024-12-10T12:55:12.055723"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000484, "longitude": -75.000571, "timestamp": "2024-12-10T12:55:12.055723"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000416, "longitude": -75.000585, "timestamp": "2024-12-10T12:55:12.192362"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 119, "timestamp": "2024-12-10T12:55:12.193050"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 37.5, "timestamp": "2024-12-10T12:55:12.364085"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 113, "timestamp": "2024-12-10T12:55:12.364085"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.8, "timestamp": "2024-12-10T12:55:12.427264"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-10T12:55:12.552307"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000465, "longitude": -75.000603, "timestamp": "2024-12-10T12:55:12.553008"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000488, "longitude": -75.000583, "timestamp": "2024-12-10T12:55:12.553008"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 94, "timestamp": "2024-12-10T12:55:12.553008"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 123, "timestamp": "2024-12-10T12:55:12.707790"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000425, "longitude": -75.000588, "timestamp": "2024-12-10T12:55:12.707790"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 78, "timestamp": "2024-12-10T12:55:12.866611"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.7, "timestamp": "2024-12-10T12:55:12.866611"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.2, "timestamp": "2024-12-10T12:55:12.944773"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.5, "timestamp": "2024-12-10T12:55:13.070227"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000481, "longitude": -75.000586, "timestamp": "2024-12-10T12:55:13.070227"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 88, "timestamp": "2024-12-10T12:55:13.070227"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000459, "longitude": -75.000592, "timestamp": "2024-12-10T12:55:13.070227"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000428, "longitude": -75.00059, "timestamp": "2024-12-10T12:55:13.226791"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 121, "timestamp": "2024-12-10T12:55:13.226791"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.9, "timestamp": "2024-12-10T12:55:13.368811"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 98, "timestamp": "2024-12-10T12:55:13.368811"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.1, "timestamp": "2024-12-10T12:55:13.460843"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 37.6, "timestamp": "2024-12-10T12:55:13.570808"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 71, "timestamp": "2024-12-10T12:55:13.570808"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000462, "longitude": -75.000582, "timestamp": "2024-12-10T12:55:13.570808"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000472, "longitude": -75.000579, "timestamp": "2024-12-10T12:55:13.570808"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 106, "timestamp": "2024-12-10T12:55:13.728403"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000436, "longitude": -75.000587, "timestamp": "2024-12-10T12:55:13.728403"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 102, "timestamp": "2024-12-10T12:55:13.884291"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.1, "timestamp": "2024-12-10T12:55:13.884922"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 38.9, "timestamp": "2024-12-10T12:55:13.962999"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 36.4, "timestamp": "2024-12-10T12:55:14.073232"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000468, "longitude": -75.000592, "timestamp": "2024-12-10T12:55:14.073232"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000475, "longitude": -75.000572, "timestamp": "2024-12-10T12:55:14.073232"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 96, "timestamp": "2024-12-10T12:55:14.073232"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000444, "longitude": -75.000583, "timestamp": "2024-12-10T12:55:14.246544"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 91, "timestamp": "2024-12-10T12:55:14.246544"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-10T12:55:14.390026"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 109, "timestamp": "2024-12-10T12:55:14.390026"}
# Sent data from player_temperature_2 (run run_001): {"temperature": 36.3, "timestamp": "2024-12-10T12:55:14.467775"}
# Sent data from player_temperature_3 (run run_001): {"temperature": 38.6, "timestamp": "2024-12-10T12:55:14.561627"}
# Sent data from gps_1 (run run_001): {"latitude": 40.000466, "longitude": -75.000579, "timestamp": "2024-12-10T12:55:14.561627"}
# Sent data from player_heart_rate_3 (run run_001): {"heart_rate": 111, "timestamp": "2024-12-10T12:55:14.562281"}
# Sent data from gps_3 (run run_001): {"latitude": 40.000475, "longitude": -75.000602, "timestamp": "2024-12-10T12:55:14.562281"}
# Sent data from player_heart_rate_2 (run run_001): {"heart_rate": 109, "timestamp": "2024-12-10T12:55:14.749031"}
# Sent data from gps_2 (run run_001): {"latitude": 40.000454, "longitude": -75.000577, "timestamp": "2024-12-10T12:55:14.749655"}
# Sent data from player_heart_rate_1 (run run_001): {"heart_rate": 103, "timestamp": "2024-12-10T12:55:14.904780"}
# Sent data from player_temperature_1 (run run_001): {"temperature": 38.3, "timestamp": "2024-12-10T12:55:14.904780"}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[12], line 113, in send_synthetic_data(device_id, run_id, schema_type)
#     112 message_count += 1
# --> 113 await asyncio.sleep(INTERVAL_SECONDS)
#
# File c:\Users\emili\anaconda3\lib\asyncio\tasks.py:652, in sleep(delay, result, loop)
#     651 try:
# --> 652     return await future
#     653 finally:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[12], line 128
#     125     await asyncio.gather(*tasks)
#     127 # Run the main function
# --> 128 await main()
#
# Cell In[12], line 125, in main()
#     118 # Generate tasks for 10 devices of each type
#     119 tasks = [
#     120     *[send_synthetic_data(f"gps_{i}", run_id, "gps") for i in range(1, 4)],
#     121     *[send_synthetic_data(f"player_heart_rate_{i}", run_id, "heart_rate") for i in range(1, 4)],
#     122     *[send_synthetic_data(f"player_temperature_{i}", run_id, "temperature") for i in range(1, 4)]
#     123 ]
# --> 125 await asyncio.gather(*tasks)
#
# CancelledError:
